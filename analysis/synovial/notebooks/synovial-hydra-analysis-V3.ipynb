# %%
import sys
import pandas as pd

sys.path.append('/opt/hydra/')

import library.analysis as hydra

# %%
exp_path = '../data/treehouse-synovial-log2TPM1-V9.tsv'
mm_path = '../data/synovial-output/MultiModalGenes'

# %%
exp = pd.read_csv(exp_path, sep='\t', index_col=0)

# %%
import numpy as np

mm = hydra.EnrichmentAnalysis(mm_path,
                              exp_path,
                              min_prob_filter=0.33,
                              gmt_path='GO')

# %%
hclust = hydra.HClust(exp.reindex(mm.get_enriched_term_genes()))
hclust.plot()

# %%
clus = hydra.MultivariateMixtureModel(data=exp.reindex(mm.get_enriched_term_genes()),
                                      center=True,
                                      gamma=5.0,
                                      variance=2.0,
                                      K=1)
# Out:
# DELETE @ lap 1.00: Disabled. Cannot delete before first complete lap, because SS that represents whole dataset is required.
# DELETE @ lap 2.00: 0/1 accepted. Ndiff 0.00.
# DELETE @ lap 3.00: 0/1 accepted. Ndiff 0.00.
# DELETE @ lap 4.00: Empty plan. 0 UIDs eligible as delete target. 0 too busy with other moves. 0 too big. 2 have past failures.
# DELETE @ lap 5.00: Empty plan. 0 UIDs eligible as delete target. 0 too busy with other moves. 0 too big. 2 have past failures.
# DELETE @ lap 6.00: Empty plan. 0 UIDs eligible as delete target. 0 too busy with other moves. 0 too big. 2 have past failures.
# DELETE @ lap 7.00: Empty plan. 0 UIDs eligible as delete target. 0 too busy with other moves. 0 too big. 2 have past failures.
# DELETE @ lap 8.00: 0/1 accepted. Ndiff 0.00.
# DELETE @ lap 9.00: 0/1 accepted. Ndiff 0.00.
# DELETE @ lap 10.00: Empty plan. 0 UIDs eligible as delete target. 0 too busy with other moves. 0 too big. 2 have past failures.
# DELETE @ lap 11.00: Empty plan. 0 UIDs eligible as delete target. 0 too busy with other moves. 0 too big. 2 have past failures.
# DELETE @ lap 12.00: Empty plan. 0 UIDs eligible as delete target. 0 too busy with other moves. 0 too big. 2 have past failures.
# DELETE @ lap 13.00: Empty plan. 0 UIDs eligible as delete target. 0 too busy with other moves. 0 too big. 2 have past failures.

# %%
cluster_feat = clus.get_cluster_features(exp=exp, 
                                         gmt='/opt/hydra/gene-sets/Human_GOBP_AllPathways_no_GO_iea_December_01_2018_symbol.gmt')

# %%
assign = pd.DataFrame(columns=['sample', 'cluster'])
for s, a in zip(exp.columns, clus.get_assignments(exp.reindex(mm.get_enriched_term_genes()))):
    assign.loc[len(assign), :] = [s, a + 1]
    
assign.set_index('sample', inplace=True)

# %%
pth = '../data/synovial-fusion.tsv'
fusion = pd.read_csv(pth, sep='\t', index_col=0)

m = [[0, 0, 0], [0, 0, 0]]

fusion_samples = {'SSX1': [], 'SSX2': []}
for sample in assign.index.values:
    if sample == 'TCGA-DX-A7EQ-01':
        continue
    c = assign.loc[sample, 'cluster']
    f = fusion.loc[sample, 'fusion']
    if f == 'SSX1':
        m[1][c - 1] += 1
        fusion_samples['SSX1'].append(sample)
        
    elif f == 'SSX2':
        m[0][c - 1] += 1
        fusion_samples['SSX2'].append(sample)
    
    else:
        raise ValueError()

print """
> library(stats)
> library(base)
> x <- rbind(c(4, 5, 2), c(13, 5, 6))
> x
     [,1] [,2] [,3]
[1,]    4    5    2
[2,]   13    5    6
> fisher.test(x)

	Fisher's Exact Test for Count Data

data:  x
p-value = 0.3237
alternative hypothesis: two.sided
"""
# Out:
# > library(stats)
# > library(base)
# > x <- rbind(c(4, 5, 2), c(13, 5, 6))
# > x
#      [,1] [,2] [,3]
# [1,]    4    5    2
# [2,]   13    5    6
# > fisher.test(x)
#
# 	Fisher's Exact Test for Count Data
#
# data:  x
# p-value = 0.3237
# alternative hypothesis: two.sided

# POSITIVE REGULATION OF LOCOMOTION%GOBP%GO:0040017   0.583333  0.818514
# NEUROPEPTIDE SIGNALING PATHWAY%GOBP%GO:0007218     -0.625000 -0.874933
# URETERIC BUD MORPHOGENESIS%GOBP%GO:0060675         -0.313276 -0.654535
# NEGATIVE REGULATION OF EPITHELIAL CELL PROLIFER... -0.454545 -0.949694
# REGULATION OF CELLULAR COMPONENT ORGANIZATION%G... -0.652174 -1.149132
# REGULATION OF CARTILAGE DEVELOPMENT%GOBP%GO:006...  0.750000  1.052375
# POSITIVE REGULATION OF PROTEIN METABOLIC PROCES... -0.652174 -1.149132
# DEVELOPMENTAL PROCESS INVOLVED IN REPRODUCTION%... -0.434783 -0.766088
# DETERMINATION OF PANCREATIC LEFT/RIGHT ASYMMETR...  1.000000  1.403166
#
#                                                     nMoreExtreme  size  \
# pathway
# ID%IOB%ID                                                    611     1
# IFN-GAMMA%IOB%IFN-GAMMA                                     2430     1
# PID_CMYB_PATHWAY%MSIGDB_C2%PID_CMYB_PATHWAY                 6717     1
# PID_RB_1PATHWAY%MSIGDB_C2%PID_RB_1PATHWAY                   3006     1
# PID_TELOMERASE_PATHWAY%MSIGDB_C2%PID_TELOMERASE...          3601     1
# PID_CASPASE_PATHWAY%MSIGDB_C2%PID_CASPASE_PATHWAY           3603     1
# PID_HNF3A_PATHWAY%MSIGDB_C2%PID_HNF3A_PATHWAY               3601     1
# PID_IL27_PATHWAY%MSIGDB_C2%PID_IL27_PATHWAY                 6717     1
# PID_SMAD2_3NUCLEAR_PATHWAY%MSIGDB_C2%PID_SMAD2_...          6717     1
# PID_HDAC_CLASSIII_PATHWAY%MSIGDB_C2%PID_HDAC_CL...          2430     1
# PID_CDC42_PATHWAY%MSIGDB_C2%PID_CDC42_PATHWAY               1192     1
# PID_NOTCH_PATHWAY%MSIGDB_C2%PID_NOTCH_PATHWAY               6717     1
# PID_REG_GR_PATHWAY%MSIGDB_C2%PID_REG_GR_PATHWAY             6717     1
# BIOCARTA_GATA3_PATHWAY%MSIGDB_C2%BIOCARTA_GATA3...          6717     1
# BIOCARTA_PML_PATHWAY%MSIGDB_C2%BIOCARTA_PML_PAT...          3006     1
# PID_NFAT_TFPATHWAY%MSIGDB_C2%PID_NFAT_TFPATHWAY             6717     1
# HALLMARK_SPERMATOGENESIS%MSIGDB_C2%HALLMARK_SPE...          5925     1
# HALLMARK_APICAL_SURFACE%MSIGDB_C2%HALLMARK_APIC...          6717     1
# HALLMARK_KRAS_SIGNALING_DN%MSIGDB_C2%HALLMARK_K...          3006     1
# HALLMARK_PANCREAS_BETA_CELLS%MSIGDB_C2%HALLMARK...           166     2
# HALLMARK_COAGULATION%MSIGDB_C2%HALLMARK_COAGULA...          4767     1
# HALLMARK_INFLAMMATORY_RESPONSE%MSIGDB_C2%HALLMA...          4767     1
# HALLMARK_COMPLEMENT%MSIGDB_C2%HALLMARK_COMPLEMENT           6717     1
# REGULATION OF TELOMERASE%PATHWAY INTERACTION DA...          3601     1
# SIGNALING EVENTS MEDIATED BY HDAC CLASS III%PAT...          2430     1
# NOTCH SIGNALING PATHWAY%PATHWAY INTERACTION DAT...          6717     1
# CDC42 SIGNALING EVENTS%PATHWAY INTERACTION DATA...          1192     1
# CASPASE CASCADE IN APOPTOSIS%PATHWAY INTERACTIO...          3603     1
# C-MYB TRANSCRIPTION FACTOR NETWORK%PATHWAY INTE...          6717     1
# GLUCOCORTICOID RECEPTOR REGULATORY NETWORK%PATH...          6717     1
# ...                                                          ...   ...
# POSITIVE REGULATION OF PROTEIN KINASE B SIGNALI...          6717     1
# REGULATION OF MAMMARY GLAND EPITHELIAL CELL PRO...          6717     1
# DETECTION OF MECHANICAL STIMULUS INVOLVED IN SE...          4767     1
# POSITIVE REGULATION OF CHEMOKINE PRODUCTION%GOB...          5925     1
# NEGATIVE REGULATION OF INFLAMMATORY RESPONSE%GO...          5313     2
# ION HOMEOSTASIS%GOBP%GO:0050801                             5925     1
# POSITIVE REGULATION OF IMMUNE SYSTEM PROCESS%GO...          6772     2
# CELL SURFACE RECEPTOR SIGNALING PATHWAY%GOBP%GO...          5313     2
# CELL PROJECTION ORGANIZATION%GOBP%GO:0030030                5925     1
# NUCLEOBASE-CONTAINING SMALL MOLECULE METABOLIC ...          5925     1
# CELLULAR PROCESS%GOBP%GO:0009987                            5769    10
# CELL COMMUNICATION%GOBP%GO:0007154                          1833     4
# NEGATIVE REGULATION OF IMMUNE RESPONSE%GOBP%GO:...          5925     1
# REGULATION OF CELL GROWTH%GOBP%GO:0001558                   4767     1
# ORGANIC SUBSTANCE TRANSPORT%GOBP%GO:0071702                 5925     1
# POSITIVE REGULATION OF CELLULAR PROCESS%GOBP%GO...          2679    16
# CAMERA-TYPE EYE DEVELOPMENT%GOBP%GO:0043010                  706     2
# ENDOTHELIAL CELL DIFFERENTIATION%GOBP%GO:0045446            3601     1
# DETECTION OF MECHANICAL STIMULUS INVOLVED IN SE...          4767     1
# REGULATION OF TOOTH MINERALIZATION%GOBP%GO:0070170          3603     1
# PANCREATIC A CELL DEVELOPMENT%GOBP%GO:0003322               1192     1
# POSITIVE REGULATION OF LOCOMOTION%GOBP%GO:0040017           6717     1
# NEUROPEPTIDE SIGNALING PATHWAY%GOBP%GO:0007218              5925     1
# URETERIC BUD MORPHOGENESIS%GOBP%GO:0060675                  5041     3
# NEGATIVE REGULATION OF EPITHELIAL CELL PROLIFER...          3105     3
# REGULATION OF CELLULAR COMPONENT ORGANIZATION%G...          2238     2
# REGULATION OF CARTILAGE DEVELOPMENT%GOBP%GO:006...          3603     1
# POSITIVE REGULATION OF PROTEIN METABOLIC PROCES...          2238     2
# DEVELOPMENTAL PROCESS INVOLVED IN REPRODUCTION%...          5313     2
# DETERMINATION OF PANCREATIC LEFT/RIGHT ASYMMETR...             0     1
#
#                                                                                   leadingEdge
# pathway
# ID%IOB%ID                                                                                PAX8
# IFN-GAMMA%IOB%IFN-GAMMA                                                                HOXA10
# PID_CMYB_PATHWAY%MSIGDB_C2%PID_CMYB_PATHWAY                                             GATA3
# PID_RB_1PATHWAY%MSIGDB_C2%PID_RB_1PATHWAY                                                PAX3
# PID_TELOMERASE_PATHWAY%MSIGDB_C2%PID_TELOMERASE...                                      NR2F2
# PID_CASPASE_PATHWAY%MSIGDB_C2%PID_CASPASE_PATHWAY                                      TFAP2A
# PID_HNF3A_PATHWAY%MSIGDB_C2%PID_HNF3A_PATHWAY                                           NR2F2
# PID_IL27_PATHWAY%MSIGDB_C2%PID_IL27_PATHWAY                                             GATA3
# PID_SMAD2_3NUCLEAR_PATHWAY%MSIGDB_C2%PID_SMAD2_...                                      GATA3
# PID_HDAC_CLASSIII_PATHWAY%MSIGDB_C2%PID_HDAC_CL...                                     HOXA10
# PID_CDC42_PATHWAY%MSIGDB_C2%PID_CDC42_PATHWAY                                            PAX6
# PID_NOTCH_PATHWAY%MSIGDB_C2%PID_NOTCH_PATHWAY                                           GATA3
# PID_REG_GR_PATHWAY%MSIGDB_C2%PID_REG_GR_PATHWAY                                         GATA3
# BIOCARTA_GATA3_PATHWAY%MSIGDB_C2%BIOCARTA_GATA3...                                      GATA3
# BIOCARTA_PML_PATHWAY%MSIGDB_C2%BIOCARTA_PML_PAT...                                       PAX3
# PID_NFAT_TFPATHWAY%MSIGDB_C2%PID_NFAT_TFPATHWAY                                         GATA3
# HALLMARK_SPERMATOGENESIS%MSIGDB_C2%HALLMARK_SPE...                                    ADCYAP1
# HALLMARK_APICAL_SURFACE%MSIGDB_C2%HALLMARK_APIC...                                      GATA3
# HALLMARK_KRAS_SIGNALING_DN%MSIGDB_C2%HALLMARK_K...                                       PAX3
# HALLMARK_PANCREAS_BETA_CELLS%MSIGDB_C2%HALLMARK...                                PAX6|NKX2-2
# HALLMARK_COAGULATION%MSIGDB_C2%HALLMARK_COAGULA...                                        HPN
# HALLMARK_INFLAMMATORY_RESPONSE%MSIGDB_C2%HALLMA...                                        HPN
# HALLMARK_COMPLEMENT%MSIGDB_C2%HALLMARK_COMPLEMENT                                       GATA3
# REGULATION OF TELOMERASE%PATHWAY INTERACTION DA...                                      NR2F2
# SIGNALING EVENTS MEDIATED BY HDAC CLASS III%PAT...                                     HOXA10
# NOTCH SIGNALING PATHWAY%PATHWAY INTERACTION DAT...                                      GATA3
# CDC42 SIGNALING EVENTS%PATHWAY INTERACTION DATA...                                       PAX6
# CASPASE CASCADE IN APOPTOSIS%PATHWAY INTERACTIO...                                     TFAP2A
# C-MYB TRANSCRIPTION FACTOR NETWORK%PATHWAY INTE...                                      GATA3
# GLUCOCORTICOID RECEPTOR REGULATORY NETWORK%PATH...                                      GATA3
# ...                                                                                       ...
# POSITIVE REGULATION OF PROTEIN KINASE B SIGNALI...                                      GATA3
# REGULATION OF MAMMARY GLAND EPITHELIAL CELL PRO...                                      GATA3
# DETECTION OF MECHANICAL STIMULUS INVOLVED IN SE...                                        HPN
# POSITIVE REGULATION OF CHEMOKINE PRODUCTION%GOB...                                    ADCYAP1
# NEGATIVE REGULATION OF INFLAMMATORY RESPONSE%GO...                              GATA3|ADCYAP1
# ION HOMEOSTASIS%GOBP%GO:0050801                                                       ADCYAP1
# POSITIVE REGULATION OF IMMUNE SYSTEM PROCESS%GO...                                GATA3|HOXA5
# CELL SURFACE RECEPTOR SIGNALING PATHWAY%GOBP%GO...                                  GATA3|HPN
# CELL PROJECTION ORGANIZATION%GOBP%GO:0030030                                          ADCYAP1
# NUCLEOBASE-CONTAINING SMALL MOLECULE METABOLIC ...                                    ADCYAP1
# CELLULAR PROCESS%GOBP%GO:0009987                                      PAX6|PAX3|TFAP2A|HOXA11
# CELL COMMUNICATION%GOBP%GO:0007154                                    GATA3|ADCYAP1|HPN|NR2F2
# NEGATIVE REGULATION OF IMMUNE RESPONSE%GOBP%GO:...                                    ADCYAP1
# REGULATION OF CELL GROWTH%GOBP%GO:0001558                                                 HPN
# ORGANIC SUBSTANCE TRANSPORT%GOBP%GO:0071702                                           ADCYAP1
# POSITIVE REGULATION OF CELLULAR PROCESS%GOBP%GO...  ZIC3|PAX6|HOXA10|PAX3|TFAP2A|HOXA11|HOXB3
# CAMERA-TYPE EYE DEVELOPMENT%GOBP%GO:0043010                                       PAX6|TFAP2A
# ENDOTHELIAL CELL DIFFERENTIATION%GOBP%GO:0045446                                        NR2F2
# DETECTION OF MECHANICAL STIMULUS INVOLVED IN SE...                                        HPN
# REGULATION OF TOOTH MINERALIZATION%GOBP%GO:0070170                                     TFAP2A
# PANCREATIC A CELL DEVELOPMENT%GOBP%GO:0003322                                            PAX6
# POSITIVE REGULATION OF LOCOMOTION%GOBP%GO:0040017                                       GATA3
# NEUROPEPTIDE SIGNALING PATHWAY%GOBP%GO:0007218                                        ADCYAP1
# URETERIC BUD MORPHOGENESIS%GOBP%GO:0060675                                               PAX8
# NEGATIVE REGULATION OF EPITHELIAL CELL PROLIFER...                            GATA3|HPN|NR2F2
# REGULATION OF CELLULAR COMPONENT ORGANIZATION%G...                                ADCYAP1|HPN
# REGULATION OF CARTILAGE DEVELOPMENT%GOBP%GO:006...                                     HOXA11
# POSITIVE REGULATION OF PROTEIN METABOLIC PROCES...                                ADCYAP1|HPN
# DEVELOPMENTAL PROCESS INVOLVED IN REPRODUCTION%...                              GATA3|ADCYAP1
# DETERMINATION OF PANCREATIC LEFT/RIGHT ASYMMETR...                                       ZIC3
#
# [1235 rows x 7 columns]

# %%
import scikit_posthocs as sp


pth = '../data/treehouse-synovial-log2TPM1-V9.estimate.gct'
est = pd.read_csv(pth, sep='\t', comment='#', header=1, index_col=0)
est.drop('Description', axis=1, inplace=True)
est.columns = [x.replace('.', '-') for x in est.columns]

pth = '../data/xCell_treehouse-synovial-log2TPM1-V9_xCell_1733072319.txt'
xcell = pd.read_csv(pth, sep='\t', index_col=0)
xcell.columns = [x.replace('.', '-') for x in xcell.columns]

immune_groups = dict((group, []) for group in assign['cluster'].unique())
immune = pd.DataFrame(columns=['sample', 'cluster', 'source', 'feature', 'value'])
for sample in assign.index.values:        
    assignment = assign.loc[sample, 'cluster']
    
    immune_groups[assignment].append(sample)
    
    for score in ['StromalScore', 'ImmuneScore', 'ESTIMATEScore']:
        _est = est.loc[score, sample].item()
        immune.loc[len(immune), :] = [sample, assignment, 'Estimate', score, _est]
        
    immune.loc[len(immune), :] = [sample, assignment, 
                                'Estimate', 'TumorPurity', 
                                np.cos(0.6049872018 + 0.0001467884 * _est)]
    
    for cell, value in xcell[sample].iteritems():
            immune.loc[len(immune), :] = [sample, assignment, 'xCell', cell, value]

skip = ['P-value', 'Pearson Correlation', 'RMSE']        
immune = immune[~immune['feature'].isin(skip)]        
immune['value'] = pd.to_numeric(immune['value'])

# %%
import collections
from scipy.stats import kruskal, f_oneway
import itertools
sigs = collections.defaultdict(list)

p_values = pd.DataFrame(columns=['source', 
                                 'feature', 
                                 'A', 
                                 'B', 
                                 'holm p-value'])

for source, rows in immune.groupby('source'):
    print source
    nfeatures = len(rows['feature'].unique())
    alpha = 1 - (1 - 0.05) ** (1.0 / nfeatures)
    for feature in rows['feature'].unique():
        print(feature)
        groups3 = []
        for i, rows in immune[immune['feature'] == feature].groupby('cluster'):
            groups3.append(list(rows['value'].values))
            print i, rows['value'].mean()
    
        try:
            stat, pvalue = kruskal(*groups3)
            print(feature, pvalue, pvalue < alpha)
        
        except Exception as e:
            print e
            continue
    
        if pvalue < alpha:
            sigs[source].append(feature)
            
            try:
                res = sp.posthoc_mannwhitney(groups3, 
                                             p_adjust='holm')
                
            except Exception as e:
                print e
                continue
            
            for i, j in itertools.combinations(range(len(groups3)),
                                               2):
                
                if i == j:
                    continue 
                    
                p_values.loc[len(p_values), :] = [source,
                                                  feature,
                                                  i, 
                                                  j,
                                                  res.iloc[i, j]]
# Out:
# Estimate
# StromalScore
# 1 -548.4996372521215
# 2 -835.3788406401089
# ('StromalScore', 0.08684255216198714, False)
# ImmuneScore
# 1 -534.9517324646492
# 2 -561.1865406182391
# ('ImmuneScore', 0.8178874300882011, False)
# ESTIMATEScore
# 1 -1618.4520307528485
# 2 -1957.7987718765887
# ('ESTIMATEScore', 0.32250402691563573, False)
# TumorPurity
# 1 0.925258477315041
# 2 0.9482426121528851
# ('TumorPurity', 0.32250402691563573, False)
# xCell
# Adipocytes
# 1 0.005421428571428571
# 2 0.013162499999999999
# ('Adipocytes', 0.3169876650016611, False)
# Astrocytes
# 1 0.0
# 2 0.0
# All numbers are identical in kruskal
# B-cells
# 1 0.008267857142857143
# 2 0.011625
# ('B-cells', 0.12211167498331582, False)
# Basophils
# 1 0.044532142857142853
# 2 0.04485
# ('Basophils', 0.8292287093853119, False)
# CD4+ T-cells
# 1 0.0
# 2 0.0
# All numbers are identical in kruskal
# CD4+ Tcm
# 1 0.01867142857142857
# 2 0.0037125
# ('CD4+ Tcm', 0.17603564400791877, False)
# CD4+ Tem
# 1 0.003414285714285714
# 2 0.0
# ('CD4+ Tem', 0.34089705751756727, False)
# CD4+ memory T-cells
# 1 0.019375
# 2 0.0330375
# ('CD4+ memory T-cells', 0.029498197836762465, False)
# CD4+ naive T-cells
# 1 0.0
# 2 0.0002
# ('CD4+ naive T-cells', 0.06136882913939924, False)
# CD8+ T-cells
# 1 0.0034785714285714285
# 2 0.014075
# ('CD8+ T-cells', 0.003496197430634208, False)
# CD8+ Tcm
# 1 0.02030714285714286
# 2 0.0459125
# ('CD8+ Tcm', 0.007468165314565143, False)
# CD8+ Tem
# 1 0.00019285714285714286
# 2 0.0
# ('CD8+ Tem', 0.592980098017395, False)
# CD8+ naive T-cells
# 1 0.007160714285714286
# 2 0.0085125
# ('CD8+ naive T-cells', 0.35729142251446044, False)
# CLP
# 1 0.002510714285714286
# 2 0.015125
# ('CLP', 0.0010416017376496552, False)
# CMP
# 1 0.014285714285714287
# 2 0.0036875000000000002
# ('CMP', 0.1459414332999889, False)
# Chondrocytes
# 1 0.0015714285714285715
# 2 0.0
# ('Chondrocytes', 0.2645867247825588, False)
# Class-switched memory B-cells
# 1 0.05253571428571429
# 2 0.044000000000000004
# ('Class-switched memory B-cells', 0.863730443935272, False)
# DC
# 1 0.031396428571428575
# 2 0.0013875
# ('DC', 0.012617377721243576, False)
# Endothelial cells
# 1 0.021439285714285716
# 2 0.026675
# ('Endothelial cells', 0.7271161725918622, False)
# Eosinophils
# 1 0.0070857142857142855
# 2 0.001425
# ('Eosinophils', 0.17388610705584379, False)
# Epithelial cells
# 1 0.07693571428571429
# 2 0.0015375
# ('Epithelial cells', 0.0072264192014251764, False)
# Erythrocytes
# 1 0.0
# 2 0.0
# All numbers are identical in kruskal
# Fibroblasts
# 1 0.0209
# 2 0.0052375
# ('Fibroblasts', 0.4142802007352858, False)
# GMP
# 1 0.07553571428571428
# 2 0.0
# ('GMP', 0.053920124724198375, False)
# HSC
# 1 0.15151785714285718
# 2 0.04375
# ('HSC', 0.0183013600043203, False)
# Hepatocytes
# 1 0.00015000000000000001
# 2 0.0
# ('Hepatocytes', 0.34089705751756727, False)
# Keratinocytes
# 1 0.016689285714285716
# 2 0.0002125
# ('Keratinocytes', 0.01507570163050087, False)
# MEP
# 1 0.015689285714285715
# 2 0.035025
# ('MEP', 0.00860130461611933, False)
# MPP
# 1 0.0
# 2 0.0
# All numbers are identical in kruskal
# MSC
# 1 0.2677857142857143
# 2 0.2451125
# ('MSC', 0.7032029658251715, False)
# Macrophages
# 1 0.0008892857142857142
# 2 5e-05
# ('Macrophages', 0.6183545532080046, False)
# Macrophages M1
# 1 0.0028321428571428573
# 2 0.0007
# ('Macrophages M1', 0.9833257810705078, False)
# Macrophages M2
# 1 0.0007285714285714286
# 2 0.0003125
# ('Macrophages M2', 0.5578093250076746, False)
# Mast cells
# 1 0.006164285714285714
# 2 0.0117625
# ('Mast cells', 0.011568178238791346, False)
# Megakaryocytes
# 1 0.013507142857142858
# 2 0.014962500000000002
# ('Megakaryocytes', 0.660516548526054, False)
# Melanocytes
# 1 0.010410714285714285
# 2 0.006187499999999999
# ('Melanocytes', 0.8485402202447287, False)
# Memory B-cells
# 1 0.005421428571428571
# 2 0.0044125
# ('Memory B-cells', 0.9823475139712624, False)
# Mesangial cells
# 1 0.0007178571428571428
# 2 0.0
# ('Mesangial cells', 0.34076184771409845, False)
# Monocytes
# 1 0.011085714285714284
# 2 0.022887499999999998
# ('Monocytes', 0.12712219493567178, False)
# Myocytes
# 1 0.03252142857142857
# 2 0.011775
# ('Myocytes', 0.29730174292535844, False)
# NK cells
# 1 0.001332142857142857
# 2 0.0004625
# ('NK cells', 0.8494493655411237, False)
# NKT
# 1 0.059439285714285715
# 2 0.0443375
# ('NKT', 0.5411854077911982, False)
# Neurons
# 1 0.005975000000000001
# 2 0.001
# ('Neurons', 0.005759219764724244, False)
# Neutrophils
# 1 0.003692857142857143
# 2 0.0065875000000000005
# ('Neutrophils', 0.4159033423575178, False)
# Osteoblast
# 1 0.0059642857142857145
# 2 0.0018874999999999999
# ('Osteoblast', 0.9167143019203522, False)
# Pericytes
# 1 0.014303571428571428
# 2 0.003425
# ('Pericytes', 0.3169876650016611, False)
# Plasma cells
# 1 0.004178571428571428
# 2 0.0033499999999999997
# ('Plasma cells', 0.7603216310597063, False)
# Platelets
# 1 0.0048285714285714295
# 2 0.0030375
# ('Platelets', 0.8753700938397119, False)
# Preadipocytes
# 1 0.020689285714285712
# 2 0.0639375
# ('Preadipocytes', 0.013216303658822155, False)
# Sebocytes
# 1 0.00795
# 2 0.0008125000000000001
# ('Sebocytes', 0.2359400151785134, False)
# Skeletal muscle
# 1 0.014164285714285716
# 2 0.0214125
# ('Skeletal muscle', 0.03101276991878654, False)
# Smooth muscle
# 1 0.15958571428571428
# 2 0.17372500000000002
# ('Smooth muscle', 0.6751427444172149, False)
# Tgd cells
# 1 0.0
# 2 0.0
# All numbers are identical in kruskal
# Th1 cells
# 1 0.03646428571428571
# 2 0.050425
# ('Th1 cells', 0.09230411363302166, False)
# Th2 cells
# 1 0.009578571428571428
# 2 0.118925
# ('Th2 cells', 0.0013762561368181, False)
# Tregs
# 1 0.01632857142857143
# 2 0.0005
# ('Tregs', 0.00793521736759803, False)
# aDC
# 1 0.134
# 2 0.16135
# ('aDC', 0.6681245981942768, False)
# cDC
# 1 0.07768571428571429
# 2 0.08313749999999999
# ('cDC', 0.6195735036812022, False)
# iDC
# 1 0.2571428571428571
# 2 0.2263375
# ('iDC', 0.8184414534878208, False)
# ly Endothelial cells
# 1 0.011189285714285716
# 2 0.012625
# ('ly Endothelial cells', 0.9063389523549199, False)
# mv Endothelial cells
# 1 0.011774999999999999
# 2 0.0159625
# ('mv Endothelial cells', 0.37218741095255303, False)
# naive B-cells
# 1 0.0004
# 2 0.000325
# ('naive B-cells', 0.8890692091511279, False)
# pDC
# 1 0.05231785714285714
# 2 0.019424999999999998
# ('pDC', 0.22085162120139099, False)
# pro B-cells
# 1 0.02054285714285714
# 2 0.0426375
# ('pro B-cells', 0.015039583106751426, False)
# ImmuneScore
# 1 -534.9517324646492
# 2 -561.1865406182391
# ('ImmuneScore', 0.8178874300882011, False)
# StromaScore
# 1 0.023882142857142855
# 2 0.022525
# ('StromaScore', 0.5543868523761422, False)
# MicroenvironmentScore
# 1 0.07281785714285714
# 2 0.069375
# ('MicroenvironmentScore', 0.8491094251746304, False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(font_scale=1.5, style='white')

interest = ['Mast cells']
mask = (immune['source'] == 'xCell') & (immune['feature'].isin(interest))

t = immune[mask]

g = sns.catplot(x='cluster', 
                y='value', 
                col='feature',
                kind='box',
                col_wrap=3,
                color='white',
                sharex=False,
                sharey=False,
                data=t,
                aspect=1.25)

for i, feature in enumerate(t['feature'].unique()):
    print i, feature
    sns.swarmplot(x='cluster',
                  y='value',
                  color='k',
                  size=5,
                  data=t[t['feature'] == feature],
                  ax=g.axes[i])

for i in range(len(g.axes)):
    g.axes[i].set_xlabel('Hydra Cluster')
    g.axes[i].set_ylabel('xCell Score')
    
plt.subplots_adjust(hspace=0.3, wspace=0.4)

#pth = 'img/CIBERSORT-Plots.svg'
#plt.savefig(pth, format='svg', bbox_inches='tight')

#pth = 'img/CIBERSORT-Plots.png'
#plt.savefig(pth, format='png', bbox_inches='tight')
# Out:
# 0 Mast cells
