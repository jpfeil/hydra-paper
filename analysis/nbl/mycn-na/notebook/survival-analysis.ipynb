# %%
library(dplyr)
library(survival)
library(survminer)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# Loading required package: ggplot2
# Loading required package: ggpubr
# Loading required package: magrittr

# %%
pth <- '../data/mycn-na-survival.tsv'

surv <- read.table(pth,
                  sep='\t',
                  header=T)

surv <- dplyr::as_tibble(surv)

# %%
surv
# Out:
#    X                   OS   vital EFS  event cluster
# 1  TARGET-30-PAITCI-01   NA NA      NA NA    NA
# 2  TARGET-30-PAITEG-01   NA NA      NA NA    NA
# 3  TARGET-30-PAIVHE-01   NA NA      NA NA    NA
# 4  TARGET-30-PALBFW-01   NA NA      NA NA    NA
# 5  TARGET-30-PALCBW-01   NA NA      NA NA    NA
# 6  TARGET-30-PALETP-01  251  1     251  1     1
# 7  TARGET-30-PALIIN-01 1395  1     684  1     1
# 8  TARGET-30-PALNVP-01 4665  0    4665  0     2
# 9  TARGET-30-PALTEG-01  551  1     523  1     1
# 10 TARGET-30-PALUYS-01 1284  1     693  1     2
# 11 TARGET-30-PALWVJ-01   NA NA      NA NA    NA
# 12 TARGET-30-PALXTB-01 4621  0    4621  0     2
# 13 TARGET-30-PAMYCE-01   NA NA      NA NA    NA
# 14 TARGET-30-PANBJH-01  920  1     168  1     2
# 15 TARGET-30-PANBSP-01  659  1     470  1     2
# 16 TARGET-30-PANKFE-01   NA NA      NA NA    NA
# 17 TARGET-30-PANNMS-01 3509  0    3509  0     1
# 18 TARGET-30-PANRHJ-01  416  1     363  1     1
# 19 TARGET-30-PANRRW-01   NA NA      NA NA    NA
# 20 TARGET-30-PANRVJ-01   NA NA      NA NA    NA
# 21 TARGET-30-PANUIF-01 3726  0    3726  0     2
# 22 TARGET-30-PANWRR-01  345  1     267  1     2
# 23 TARGET-30-PANYGR-01  283  1     281  1     2
# 24 TARGET-30-PANZPV-01   NA NA      NA NA    NA
# 25 TARGET-30-PANZVU-01  934  1     934  1     1
# 26 TARGET-30-PAPBGH-01  723  1     470  1     2
# 27 TARGET-30-PAPBZI-01  430  1     172  1     2
# 28 TARGET-30-PAPEAV-01 3462  0    3462  0     2
# 29 TARGET-30-PAPHPE-01  470  1     453  1     2
# 30 TARGET-30-PAPKXS-01 2384  1     978  1     1
# ⋮  ⋮                   ⋮    ⋮     ⋮    ⋮     ⋮
# 41 TARGET-30-PARGKK-01 1321  1    1075  1     2
# 42 TARGET-30-PARHAM-01 2466  1      38  1     2
# 43 TARGET-30-PARHAM-02 2466  1      38  1     2
# 44 TARGET-30-PARKGJ-01   NA NA      NA NA    NA
# 45 TARGET-30-PARSBI-01 1743  1    1377  1     1
# 46 TARGET-30-PARYNK-01 2351  0    2351  0     1
# 47 TARGET-30-PARZIP-01 2511  0     632  1     1
# 48 TARGET-30-PASFGG-01  700  1     700  1     1
# 49 TARGET-30-PASMNT-01 1696  1     233  1     1
# 50 TARGET-30-PASNEF-01 2213  0    2213  0     1
# 51 TARGET-30-PASPER-01 2087  0     638  1     2
# 52 TARGET-30-PASRFS-01 2075  0    1675  1     1
# 53 TARGET-30-PASSRS-01 1319  1     861  1     2
# 54 TARGET-30-PASTCN-01 1033  1     870  1     1
# 55 TARGET-30-PASTKC-01   NA NA      NA NA    NA
# 56 TARGET-30-PASUCB-01 1976  0    1976  0     2
# 57 TARGET-30-PASUYG-01 2193  0     505  1     2
# 58 TARGET-30-PASWIJ-01 1940  0    1940  0     1
# 59 TARGET-30-PASXHE-01 2098  0    2098  0     1
# 60 TARGET-30-PASXRJ-01 1837  0     266  1     1
# 61 TARGET-30-PASYPX-01 2215  0     296  1     1
# 62 TARGET-30-PATCFL-01 2125  0    2125  0     2
# 63 TARGET-30-PATDXC-01  916  1     444  1     1
# 64 TARGET-30-PATFCY-01  787  1     787  1     2
# 65 TARGET-30-PATGLU-01 1330  1     715  1     1
# 66 TARGET-30-PATHVK-01 1807  0     171  1     2
# 67 TARGET-30-PATINJ-01  822  1     736  1     1
# 68 TARGET-30-PATNKP-02 1549  1     616  1     2
# 69 TARGET-30-PATYIL-01  481  1     239  1     2
# 70 TARGET-30-PATYIL-02  481  1     239  1     2

# %%
fit <- survfit(Surv(OS, vital) ~ cluster, data=surv)
g <- ggsurvplot(fit, conf.int=F, pval=T, risk.table=TRUE)
g
# Out:
# Warning message:
# “The `printer` argument is deprecated as of rlang 0.3.0.
# This warning is displayed once per session.”Warning message:
# “`quo_is_lang()` is deprecated as of rlang 0.2.0.
# Please use `quo_is_call()` instead.
# This warning is displayed once per session.”Warning message:
# “`is_lang()` is deprecated as of rlang 0.2.0.
# Please use `is_call()` instead.
# This warning is displayed once per session.”Warning message:
# “Assigning non-quosure objects to quosure lists is deprecated as of rlang 0.3.0.
# Please coerce to a bare list beforehand with `as.list()`
# This warning is displayed once per session.”
# plot without title

# %%
fit <- survfit(Surv(EFS, vital) ~ cluster, data=surv)
g <- ggsurvplot(fit, conf.int=F, pval=T, risk.table=TRUE)
g
# Out:
# plot without title
