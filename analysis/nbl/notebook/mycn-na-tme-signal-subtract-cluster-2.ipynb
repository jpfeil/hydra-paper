# %%
# %matplotlib inline
import pandas as pd
import itertools
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
import bnpy
import warnings
from scipy import stats
import random

from scipy.stats import kruskal, f_oneway
import collections
import scikit_posthocs as sp

warnings.filterwarnings('ignore')

# %%
pth = '../data/expression/target-high-risk-nbl-mycn-na-exp-2018-11-12.tsv'

exp = pd.read_csv(pth, sep='\t', index_col=0)

# %%
pth = '../data/archive/mycn-na-nbl-0.2-assign-2019-03-02.tsv'

assign = pd.read_csv(pth, sep='\t', index_col=0)

# %%
_dir = '../data/gsea/'

sub_cohort = collections.defaultdict(list)
sub_cohort_unique = collections.defaultdict(list)
sub_clust_unique = collections.defaultdict(list)

interest = ['HUMORAL IMMUNE RESPONSE MEDIATED BY CIRCULATING IMMUNOGLOBULIN%GOBP%GO:0002455',
            'COMPLEMENT ACTIVATION, CLASSICAL PATHWAY%GOBP%GO:0006958',
            'IMMUNOGLOBULIN MEDIATED IMMUNE RESPONSE%GOBP%GO:0016064',
            'LEUKOCYTE DEGRANULATION%GOBP%GO:0043299',
            'B CELL MEDIATED IMMUNITY%GOBP%GO:0019724']

cluster2_immune = []
for cluster, rows in assign.groupby('1'):
    samps = rows.index.values
    for samp in samps:
    
        pth = os.path.join(_dir, 'sub_cohort', str(cluster), samp)        
        f1 = pd.read_csv(pth, index_col=0)
        f1 = f1[(f1['padj'] < 0.05) & (f1['ES'] > 0.0)]
        
        pth = os.path.join(_dir, 'sub_clust', str(cluster), samp)
        f2 = pd.read_csv(pth, index_col=0)
        f2 = f2[(f2['padj'] < 0.05) & (f2['ES'] > 0.0)]
        
        if cluster == 2:
            print samp
            print f1.sort_values('NES', ascending=False)['NES'].head(10)
            print '\n'
            print f2.sort_values('NES', ascending=False)['NES'].head(10)
            print '\n\n'
            
            if len(f2.index.intersection(interest)) > 0:
                cluster2_immune.append(samp)
            
        
        sub_cohort_unique[cluster].extend(list(set(f1.index.values) - set(f2.index.values)))
        sub_clust_unique[cluster].extend(list(set(f2.index.values) - set(f1.index.values)))
# Out:
# TARGET-30-PALNVP-01
# pathway
# HALLMARK_OXIDATIVE_PHOSPHORYLATION%MSIGDB_C2%HALLMARK_OXIDATIVE_PHOSPHORYLATION                                                                4.466123
# RESPIRATORY ELECTRON TRANSPORT, ATP SYNTHESIS BY CHEMIOSMOTIC COUPLING, AND HEAT PRODUCTION BY UNCOUPLING PROTEINS.%REACTOME%R-HSA-163200.1    4.159723
# ELECTRON TRANSPORT CHAIN (OXPHOS SYSTEM IN MITOCHONDRIA)%WIKIPATHWAYS_20181110%WP111%HOMO SAPIENS                                              4.108202
# ATP METABOLIC PROCESS%GOBP%GO:0046034                                                                                                          4.074717
# OXIDATIVE PHOSPHORYLATION%GOBP%GO:0006119                                                                                                      4.052672
# NUCLEOSIDE MONOPHOSPHATE METABOLIC PROCESS%GOBP%GO:0009123                                                                                     3.957874
# RIBONUCLEOSIDE MONOPHOSPHATE METABOLIC PROCESS%GOBP%GO:0009161                                                                                 3.951778
# PURINE RIBONUCLEOSIDE MONOPHOSPHATE METABOLIC PROCESS%GOBP%GO:0009167                                                                          3.925640
# PURINE NUCLEOSIDE MONOPHOSPHATE METABOLIC PROCESS%GOBP%GO:0009126                                                                              3.925640
# RESPIRATORY ELECTRON TRANSPORT%REACTOME DATABASE ID RELEASE 66%611105                                                                          3.910490
# Name: NES, dtype: float64
#
#
# pathway
# HALLMARK_OXIDATIVE_PHOSPHORYLATION%MSIGDB_C2%HALLMARK_OXIDATIVE_PHOSPHORYLATION                                                                4.301614
# ELECTRON TRANSPORT CHAIN (OXPHOS SYSTEM IN MITOCHONDRIA)%WIKIPATHWAYS_20181110%WP111%HOMO SAPIENS                                              4.130323
# OXIDATIVE PHOSPHORYLATION%GOBP%GO:0006119                                                                                                      4.103622
# RESPIRATORY ELECTRON TRANSPORT, ATP SYNTHESIS BY CHEMIOSMOTIC COUPLING, AND HEAT PRODUCTION BY UNCOUPLING PROTEINS.%REACTOME%R-HSA-163200.1    4.020508
# ATP METABOLIC PROCESS%GOBP%GO:0046034                                                                                                          3.954466
# RESPIRATORY ELECTRON TRANSPORT%REACTOME DATABASE ID RELEASE 66%611105                                                                          3.772570
# RIBONUCLEOSIDE MONOPHOSPHATE METABOLIC PROCESS%GOBP%GO:0009161                                                                                 3.771404
# NUCLEOSIDE MONOPHOSPHATE METABOLIC PROCESS%GOBP%GO:0009123                                                                                     3.765638
# PURINE RIBONUCLEOSIDE MONOPHOSPHATE METABOLIC PROCESS%GOBP%GO:0009167                                                                          3.752226
# PURINE NUCLEOSIDE MONOPHOSPHATE METABOLIC PROCESS%GOBP%GO:0009126                                                                              3.752226
# Name: NES, dtype: float64
#
#
#
# TARGET-30-PALUYS-01
# pathway
# ACTIVATION OF RRNA EXPRESSION BY ERCC6 (CSB) AND EHMT2 (G9A)%REACTOME DATABASE ID RELEASE 66%427389                                        2.978050
# DNA METHYLATION%REACTOME DATABASE ID RELEASE 66%5334118                                                                                    2.931526
# METABOLIC REPROGRAMMING IN COLON CANCER%WIKIPATHWAYS_20181110%WP4290%HOMO SAPIENS                                                          2.926099
# MEIOTIC RECOMBINATION%REACTOME DATABASE ID RELEASE 66%912446                                                                               2.902964
# RMTS METHYLATE HISTONE ARGININES%REACTOME DATABASE ID RELEASE 66%3214858                                                                   2.871934
# HDACS DEACETYLATE HISTONES%REACTOME DATABASE ID RELEASE 66%3214815                                                                         2.866244
# ACTIVATED PKN1 STIMULATES TRANSCRIPTION OF AR (ANDROGEN RECEPTOR) REGULATED GENES KLK2 AND KLK3%REACTOME DATABASE ID RELEASE 66%5625886    2.863058
# PRC2 METHYLATES HISTONES AND DNA%REACTOME%R-HSA-212300.1                                                                                   2.759475
# CHROMATIN MODIFYING ENZYMES%REACTOME DATABASE ID RELEASE 66%3247509                                                                        2.740509
# CHROMATIN ORGANIZATION%REACTOME%R-HSA-4839726.2                                                                                            2.740509
# Name: NES, dtype: float64
#
#
# pathway
# IMMUNOREGULATORY INTERACTIONS BETWEEN A LYMPHOID AND A NON-LYMPHOID CELL%REACTOME DATABASE ID RELEASE 66%198933                 3.070725
# CELL KILLING%GOBP%GO:0001906                                                                                                    2.979999
# RMTS METHYLATE HISTONE ARGININES%REACTOME DATABASE ID RELEASE 66%3214858                                                        2.966992
# DNA METHYLATION%REACTOME DATABASE ID RELEASE 66%5334118                                                                         2.937443
# PRC2 METHYLATES HISTONES AND DNA%REACTOME%R-HSA-212300.1                                                                        2.862608
# REGULATION OF LYMPHOCYTE ACTIVATION%GOBP%GO:0051249                                                                             2.846207
# HDACS DEACETYLATE HISTONES%REACTOME DATABASE ID RELEASE 66%3214815                                                              2.834696
# POSITIVE REGULATION OF LYMPHOCYTE ACTIVATION%GOBP%GO:0051251                                                                    2.826826
# ACTIVATION OF ANTERIOR HOX GENES IN HINDBRAIN DEVELOPMENT DURING EARLY EMBRYOGENESIS%REACTOME DATABASE ID RELEASE 66%5617472    2.812877
# ACTIVATION OF HOX GENES DURING DIFFERENTIATION%REACTOME DATABASE ID RELEASE 66%5619507                                          2.812877
# Name: NES, dtype: float64
#
#
#
# TARGET-30-PALXTB-01
# pathway
# EUKARYOTIC TRANSLATION ELONGATION%REACTOME DATABASE ID RELEASE 66%156842                                               4.126841
# PEPTIDE CHAIN ELONGATION%REACTOME DATABASE ID RELEASE 66%156902                                                        4.041336
# VIRAL MRNA TRANSLATION%REACTOME%R-HSA-192823.3                                                                         3.917609
# SRP-DEPENDENT COTRANSLATIONAL PROTEIN TARGETING TO MEMBRANE%REACTOME%R-HSA-1799339.1                                   3.863329
# FORMATION OF A POOL OF FREE 40S SUBUNITS%REACTOME DATABASE ID RELEASE 66%72689                                         3.809138
# SELENOCYSTEINE SYNTHESIS%REACTOME%R-HSA-2408557.2                                                                      3.732666
# SRP-DEPENDENT COTRANSLATIONAL PROTEIN TARGETING TO MEMBRANE%GOBP%GO:0006614                                            3.624846
# COTRANSLATIONAL PROTEIN TARGETING TO MEMBRANE%GOBP%GO:0006613                                                          3.618704
# NONSENSE MEDIATED DECAY (NMD) INDEPENDENT OF THE EXON JUNCTION COMPLEX (EJC)%REACTOME DATABASE ID RELEASE 66%975956    3.559373
# EUKARYOTIC TRANSLATION TERMINATION%REACTOME%R-HSA-72764.4                                                              3.556550
# Name: NES, dtype: float64
#
#
# pathway
# IMMUNOREGULATORY INTERACTIONS BETWEEN A LYMPHOID AND A NON-LYMPHOID CELL%REACTOME DATABASE ID RELEASE 66%198933    4.560777
# MYELOID LEUKOCYTE MIGRATION%GOBP%GO:0097529                                                                        4.063903
# LEUKOCYTE CHEMOTAXIS%GOBP%GO:0030595                                                                               4.027188
# GRANULOCYTE CHEMOTAXIS%GOBP%GO:0071621                                                                             4.016457
# CELLULAR RESPONSE TO INTERFERON-GAMMA%GOBP%GO:0071346                                                              3.999895
# RESPONSE TO INTERFERON-GAMMA%GOBP%GO:0034341                                                                       3.967484
# GRANULOCYTE MIGRATION%GOBP%GO:0097530                                                                              3.927193
# REGULATION OF T CELL ACTIVATION%GOBP%GO:0050863                                                                    3.904834
# REGULATION OF T CELL PROLIFERATION%GOBP%GO:0042129                                                                 3.889598
# REGULATION OF LEUKOCYTE PROLIFERATION%GOBP%GO:0070663                                                              3.880988
# Name: NES, dtype: float64
#
#
#
# TARGET-30-PANBJH-01
# pathway
# HALLMARK_E2F_TARGETS%MSIGDB_C2%HALLMARK_E2F_TARGETS                            2.770426
# POSITIVE REGULATION OF MITOTIC SISTER CHROMATID SEGREGATION%GOBP%GO:0062033    2.364043
# PIRNA METABOLIC PROCESS%GOBP%GO:0034587                                        2.349988
# HALLMARK_G2M_CHECKPOINT%MSIGDB_C2%HALLMARK_G2M_CHECKPOINT                      2.344643
# MITOTIC PROMETAPHASE%REACTOME DATABASE ID RELEASE 66%68877                     2.292195
# RETINOBLASTOMA GENE IN CANCER%WIKIPATHWAYS_20181110%WP2446%HOMO SAPIENS        2.196822
# SISTER CHROMATID COHESION%GOBP%GO:0007062                                      2.184679
# REGULATION OF G2/M TRANSITION OF MITOTIC CELL CYCLE%GOBP%GO:0010389            2.164107
# CHOLESTEROL BIOSYNTHESIS%REACTOME DATABASE ID RELEASE 66%191273                2.162919
# MEIOTIC CELL CYCLE%GOBP%GO:0051321                                             2.152499
# Name: NES, dtype: float64
#
#
# pathway
# HALLMARK_G2M_CHECKPOINT%MSIGDB_C2%HALLMARK_G2M_CHECKPOINT     2.497272
# HALLMARK_E2F_TARGETS%MSIGDB_C2%HALLMARK_E2F_TARGETS           2.453764
# MITOTIC PROMETAPHASE%REACTOME DATABASE ID RELEASE 66%68877    2.300188
# CHROMOSOME SEGREGATION%GOBP%GO:0007059                        2.230581
# REGULATION OF MITOTIC NUCLEAR DIVISION%GOBP%GO:0007088        2.224417
# NUCLEAR CHROMOSOME SEGREGATION%GOBP%GO:0098813                2.220225
# REGULATION OF NUCLEAR DIVISION%GOBP%GO:0051783                2.210332
# NUCLEAR DIVISION%GOBP%GO:0000280                              2.203704
# POSITIVE REGULATION OF NUCLEAR DIVISION%GOBP%GO:0051785       2.202395
# MITOTIC CELL CYCLE PHASE TRANSITION%GOBP%GO:0044772           2.176486
# Name: NES, dtype: float64
# TARGET-30-PANBSP-01
# pathway
# MAJOR PATHWAY OF RRNA PROCESSING IN THE NUCLEOLUS AND CYTOSOL%REACTOME DATABASE ID RELEASE 66%6791226       4.428339
# RRNA PROCESSING IN THE NUCLEUS AND CYTOSOL%REACTOME%R-HSA-8868773.2                                         4.415805
# RRNA PROCESSING%REACTOME DATABASE ID RELEASE 66%72312                                                       4.402639
# L13A-MEDIATED TRANSLATIONAL SILENCING OF CERULOPLASMIN EXPRESSION%REACTOME DATABASE ID RELEASE 66%156827    4.399370
# CAP-DEPENDENT TRANSLATION INITIATION%REACTOME DATABASE ID RELEASE 66%72737                                  4.388685
# EUKARYOTIC TRANSLATION INITIATION%REACTOME DATABASE ID RELEASE 66%72613                                     4.388685
# TRANSLATIONAL INITIATION%GOBP%GO:0006413                                                                    4.380276
# GTP HYDROLYSIS AND JOINING OF THE 60S RIBOSOMAL SUBUNIT%REACTOME DATABASE ID RELEASE 66%72706               4.368776
# FORMATION OF A POOL OF FREE 40S SUBUNITS%REACTOME DATABASE ID RELEASE 66%72689                              4.333469
# EUKARYOTIC TRANSLATION TERMINATION%REACTOME%R-HSA-72764.4                                                   4.230703
# Name: NES, dtype: float64
#
#
# pathway
# RRNA PROCESSING IN THE NUCLEUS AND CYTOSOL%REACTOME%R-HSA-8868773.2                                         4.031748
# CAP-DEPENDENT TRANSLATION INITIATION%REACTOME DATABASE ID RELEASE 66%72737                                  4.016991
# EUKARYOTIC TRANSLATION INITIATION%REACTOME DATABASE ID RELEASE 66%72613                                     4.016991
# MAJOR PATHWAY OF RRNA PROCESSING IN THE NUCLEOLUS AND CYTOSOL%REACTOME DATABASE ID RELEASE 66%6791226       4.014441
# RRNA PROCESSING%REACTOME DATABASE ID RELEASE 66%72312                                                       4.001344
# GTP HYDROLYSIS AND JOINING OF THE 60S RIBOSOMAL SUBUNIT%REACTOME DATABASE ID RELEASE 66%72706               3.943017
# L13A-MEDIATED TRANSLATIONAL SILENCING OF CERULOPLASMIN EXPRESSION%REACTOME DATABASE ID RELEASE 66%156827    3.931099
# TRANSLATIONAL INITIATION%GOBP%GO:0006413                                                                    3.930667
# FORMATION OF A POOL OF FREE 40S SUBUNITS%REACTOME DATABASE ID RELEASE 66%72689                              3.877507
# PEPTIDE CHAIN ELONGATION%REACTOME DATABASE ID RELEASE 66%156902                                             3.764189
# Name: NES, dtype: float64
#
#
#
# TARGET-30-PANUIF-01
# pathway
# EUKARYOTIC TRANSLATION ELONGATION%REACTOME DATABASE ID RELEASE 66%156842               3.185664
# VIRAL MRNA TRANSLATION%REACTOME%R-HSA-192823.3                                         3.146308
# PEPTIDE CHAIN ELONGATION%REACTOME DATABASE ID RELEASE 66%156902                        3.134896
# FORMATION OF A POOL OF FREE 40S SUBUNITS%REACTOME DATABASE ID RELEASE 66%72689         3.079766
# SELENOCYSTEINE SYNTHESIS%REACTOME%R-HSA-2408557.2                                      3.039551
# COLLAGEN FORMATION%REACTOME%R-HSA-1474290.1                                            3.027646
# EUKARYOTIC TRANSLATION TERMINATION%REACTOME%R-HSA-72764.4                              2.948241
# SRP-DEPENDENT COTRANSLATIONAL PROTEIN TARGETING TO MEMBRANE%GOBP%GO:0006614            2.895061
# COLLAGEN BIOSYNTHESIS AND MODIFYING ENZYMES%REACTOME DATABASE ID RELEASE 66%1650814    2.876321
# NABA_BASEMENT_MEMBRANES%MSIGDB_C2%NABA_BASEMENT_MEMBRANES                              2.836987
# Name: NES, dtype: float64
#
#
# pathway
# HALLMARK_TNFA_SIGNALING_VIA_NFKB%MSIGDB_C2%HALLMARK_TNFA_SIGNALING_VIA_NFKB                                                               3.954220
# EXTRACELLULAR MATRIX ORGANIZATION%GOBP%GO:0030198                                                                                         3.459837
# COLLAGEN FORMATION%REACTOME%R-HSA-1474290.1                                                                                               3.459249
# EXTRACELLULAR STRUCTURE ORGANIZATION%GOBP%GO:0043062                                                                                      3.312553
# COLLAGEN BIOSYNTHESIS AND MODIFYING ENZYMES%REACTOME DATABASE ID RELEASE 66%1650814                                                       3.290479
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION%MSIGDB_C2%HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION                                           3.193740
# ASSEMBLY OF COLLAGEN FIBRILS AND OTHER MULTIMERIC STRUCTURES%REACTOME%R-HSA-2022090.3                                                     3.156662
# COLLAGEN METABOLIC PROCESS%GOBP%GO:0032963                                                                                                3.135471
# BETA1 INTEGRIN CELL SURFACE INTERACTIONS%PATHWAY INTERACTION DATABASE NCI-NATURE CURATED DATA%BETA1 INTEGRIN CELL SURFACE INTERACTIONS    3.112867
# PID_INTEGRIN1_PATHWAY%MSIGDB_C2%PID_INTEGRIN1_PATHWAY                                                                                     3.112867
# Name: NES, dtype: float64
#
#
#
# TARGET-30-PANWRR-01
# pathway
# EUKARYOTIC TRANSLATION TERMINATION%REACTOME%R-HSA-72764.4                                                              3.394648
# RRNA PROCESSING IN THE NUCLEUS AND CYTOSOL%REACTOME%R-HSA-8868773.2                                                    3.354046
# MAJOR PATHWAY OF RRNA PROCESSING IN THE NUCLEOLUS AND CYTOSOL%REACTOME DATABASE ID RELEASE 66%6791226                  3.342790
# NONSENSE MEDIATED DECAY (NMD) INDEPENDENT OF THE EXON JUNCTION COMPLEX (EJC)%REACTOME DATABASE ID RELEASE 66%975956    3.308535
# FORMATION OF A POOL OF FREE 40S SUBUNITS%REACTOME DATABASE ID RELEASE 66%72689                                         3.297781
# RRNA PROCESSING%REACTOME DATABASE ID RELEASE 66%72312                                                                  3.269332
# PEPTIDE CHAIN ELONGATION%REACTOME DATABASE ID RELEASE 66%156902                                                        3.253858
# L13A-MEDIATED TRANSLATIONAL SILENCING OF CERULOPLASMIN EXPRESSION%REACTOME DATABASE ID RELEASE 66%156827               3.248494
# EUKARYOTIC TRANSLATION ELONGATION%REACTOME DATABASE ID RELEASE 66%156842                                               3.231627
# VIRAL MRNA TRANSLATION%REACTOME%R-HSA-192823.3                                                                         3.199964
# Name: NES, dtype: float64
#
#
# pathway
# EUKARYOTIC TRANSLATION TERMINATION%REACTOME%R-HSA-72764.4                                                              2.754825
# NONSENSE MEDIATED DECAY (NMD) INDEPENDENT OF THE EXON JUNCTION COMPLEX (EJC)%REACTOME DATABASE ID RELEASE 66%975956    2.628980
# VIRAL MRNA TRANSLATION%REACTOME%R-HSA-192823.3                                                                         2.569679
# PEPTIDE CHAIN ELONGATION%REACTOME DATABASE ID RELEASE 66%156902                                                        2.566368
# FORMATION OF A POOL OF FREE 40S SUBUNITS%REACTOME DATABASE ID RELEASE 66%72689                                         2.562934
# SELENOCYSTEINE SYNTHESIS%REACTOME%R-HSA-2408557.2                                                                      2.544057
# EUKARYOTIC TRANSLATION ELONGATION%REACTOME DATABASE ID RELEASE 66%156842                                               2.534022
# CYTOPLASMIC RIBOSOMAL PROTEINS%WIKIPATHWAYS_20181110%WP477%HOMO SAPIENS                                                2.458197
# RRNA PROCESSING IN THE NUCLEUS AND CYTOSOL%REACTOME%R-HSA-8868773.2                                                    2.437427
# MAJOR PATHWAY OF RRNA PROCESSING IN THE NUCLEOLUS AND CYTOSOL%REACTOME DATABASE ID RELEASE 66%6791226                  2.399059
# Name: NES, dtype: float64
#
#
#
# TARGET-30-PANYGR-01
# pathway
# HALLMARK_MYC_TARGETS_V1%MSIGDB_C2%HALLMARK_MYC_TARGETS_V1    4.293132
# TRANSLATION%REACTOME%R-HSA-72766.3                           4.223172
# TRANSLATION%GOBP%GO:0006412                                  4.116447
# RIBOSOME BIOGENESIS%GOBP%GO:0042254                          3.943079
# PEPTIDE BIOSYNTHETIC PROCESS%GOBP%GO:0043043                 3.927868
# RIBONUCLEOPROTEIN COMPLEX BIOGENESIS%GOBP%GO:0022613         3.795504
# RRNA PROCESSING%GOBP%GO:0006364                              3.781195
# NCRNA METABOLIC PROCESS%GOBP%GO:0034660                      3.735015
# NCRNA PROCESSING%GOBP%GO:0034470                             3.695012
# HALLMARK_E2F_TARGETS%MSIGDB_C2%HALLMARK_E2F_TARGETS          3.694568
# Name: NES, dtype: float64
#
#
# pathway
# HALLMARK_E2F_TARGETS%MSIGDB_C2%HALLMARK_E2F_TARGETS                       3.528685
# PROCESSING OF CAPPED INTRON-CONTAINING PRE-MRNA%REACTOME%R-HSA-72203.3    3.426064
# HALLMARK_MYC_TARGETS_V1%MSIGDB_C2%HALLMARK_MYC_TARGETS_V1                 3.310688
# HALLMARK_G2M_CHECKPOINT%MSIGDB_C2%HALLMARK_G2M_CHECKPOINT                 3.290335
# PRE-MRNA SPLICING%REACTOME DATABASE ID RELEASE 66%72163                   3.287848
# MRNA SPLICING%REACTOME%R-HSA-72172.3                                      3.263337
# CELL CYCLE, MITOTIC%REACTOME%R-HSA-69278.3                                3.106299
# RNA SPLICING, VIA TRANSESTERIFICATION REACTIONS%GOBP%GO:0000375           3.034089
# CELL CYCLE CHECKPOINTS%REACTOME%R-HSA-69620.1                             3.022098
# DNA REPLICATION%REACTOME DATABASE ID RELEASE 66%69306                     3.009965
# Name: NES, dtype: float64
# TARGET-30-PAPBGH-01
# pathway
# HALLMARK_MYC_TARGETS_V1%MSIGDB_C2%HALLMARK_MYC_TARGETS_V1                                                   4.414834
# L13A-MEDIATED TRANSLATIONAL SILENCING OF CERULOPLASMIN EXPRESSION%REACTOME DATABASE ID RELEASE 66%156827    4.387912
# TRANSLATION%REACTOME%R-HSA-72766.3                                                                          4.376442
# GTP HYDROLYSIS AND JOINING OF THE 60S RIBOSOMAL SUBUNIT%REACTOME DATABASE ID RELEASE 66%72706               4.365843
# RRNA PROCESSING%REACTOME DATABASE ID RELEASE 66%72312                                                       4.349855
# RRNA PROCESSING IN THE NUCLEUS AND CYTOSOL%REACTOME%R-HSA-8868773.2                                         4.329756
# EUKARYOTIC TRANSLATION INITIATION%REACTOME DATABASE ID RELEASE 66%72613                                     4.313322
# CAP-DEPENDENT TRANSLATION INITIATION%REACTOME DATABASE ID RELEASE 66%72737                                  4.313322
# TRANSLATION%GOBP%GO:0006412                                                                                 4.297826
# MAJOR PATHWAY OF RRNA PROCESSING IN THE NUCLEOLUS AND CYTOSOL%REACTOME DATABASE ID RELEASE 66%6791226       4.275377
# Name: NES, dtype: float64
#
#
# pathway
# TRANSLATIONAL INITIATION%GOBP%GO:0006413                                                                    3.851062
# HALLMARK_MYC_TARGETS_V1%MSIGDB_C2%HALLMARK_MYC_TARGETS_V1                                                   3.816784
# L13A-MEDIATED TRANSLATIONAL SILENCING OF CERULOPLASMIN EXPRESSION%REACTOME DATABASE ID RELEASE 66%156827    3.815767
# RRNA PROCESSING%REACTOME DATABASE ID RELEASE 66%72312                                                       3.760705
# GTP HYDROLYSIS AND JOINING OF THE 60S RIBOSOMAL SUBUNIT%REACTOME DATABASE ID RELEASE 66%72706               3.747032
# RRNA PROCESSING IN THE NUCLEUS AND CYTOSOL%REACTOME%R-HSA-8868773.2                                         3.727196
# EUKARYOTIC TRANSLATION INITIATION%REACTOME DATABASE ID RELEASE 66%72613                                     3.688745
# CAP-DEPENDENT TRANSLATION INITIATION%REACTOME DATABASE ID RELEASE 66%72737                                  3.688745
# FORMATION OF A POOL OF FREE 40S SUBUNITS%REACTOME DATABASE ID RELEASE 66%72689                              3.687451
# MAJOR PATHWAY OF RRNA PROCESSING IN THE NUCLEOLUS AND CYTOSOL%REACTOME DATABASE ID RELEASE 66%6791226       3.648040
# Name: NES, dtype: float64
#
#
#
# TARGET-30-PAPBZI-01
# pathway
# L13A-MEDIATED TRANSLATIONAL SILENCING OF CERULOPLASMIN EXPRESSION%REACTOME DATABASE ID RELEASE 66%156827    4.568501
# CAP-DEPENDENT TRANSLATION INITIATION%REACTOME DATABASE ID RELEASE 66%72737                                  4.488179
# EUKARYOTIC TRANSLATION INITIATION%REACTOME DATABASE ID RELEASE 66%72613                                     4.488179
# GTP HYDROLYSIS AND JOINING OF THE 60S RIBOSOMAL SUBUNIT%REACTOME DATABASE ID RELEASE 66%72706               4.480554
# FORMATION OF A POOL OF FREE 40S SUBUNITS%REACTOME DATABASE ID RELEASE 66%72689                              4.424575
# TRANSLATIONAL INITIATION%GOBP%GO:0006413                                                                    4.350215
# CYTOPLASMIC RIBOSOMAL PROTEINS%WIKIPATHWAYS_20181110%WP477%HOMO SAPIENS                                     4.310067
# PEPTIDE CHAIN ELONGATION%REACTOME DATABASE ID RELEASE 66%156902                                             4.263341
# EUKARYOTIC TRANSLATION TERMINATION%REACTOME%R-HSA-72764.4                                                   4.249138
# EUKARYOTIC TRANSLATION ELONGATION%REACTOME DATABASE ID RELEASE 66%156842                                    4.244284
# Name: NES, dtype: float64
#
#
# Series([], Name: NES, dtype: float64)
#
#
#
# TARGET-30-PAPEAV-01
# pathway
# EUKARYOTIC TRANSLATION ELONGATION%REACTOME DATABASE ID RELEASE 66%156842                                    7.261255
# FORMATION OF A POOL OF FREE 40S SUBUNITS%REACTOME DATABASE ID RELEASE 66%72689                              7.256218
# PEPTIDE CHAIN ELONGATION%REACTOME DATABASE ID RELEASE 66%156902                                             7.159492
# L13A-MEDIATED TRANSLATIONAL SILENCING OF CERULOPLASMIN EXPRESSION%REACTOME DATABASE ID RELEASE 66%156827    7.112600
# EUKARYOTIC TRANSLATION INITIATION%REACTOME DATABASE ID RELEASE 66%72613                                     7.112523
# CAP-DEPENDENT TRANSLATION INITIATION%REACTOME DATABASE ID RELEASE 66%72737                                  7.112523
# SELENOCYSTEINE SYNTHESIS%REACTOME%R-HSA-2408557.2                                                           7.093772
# VIRAL MRNA TRANSLATION%REACTOME%R-HSA-192823.3                                                              7.048237
# GTP HYDROLYSIS AND JOINING OF THE 60S RIBOSOMAL SUBUNIT%REACTOME DATABASE ID RELEASE 66%72706               7.041353
# EUKARYOTIC TRANSLATION TERMINATION%REACTOME%R-HSA-72764.4                                                   7.012998
# Name: NES, dtype: float64
#
#
# Series([], Name: NES, dtype: float64)
#
#
#
# TARGET-30-PAPHPE-01
# pathway
# SODIUM ION TRANSPORT%GOBP%GO:0006814                                            2.752308
# NEUROTRANSMITTER RELEASE CYCLE%REACTOME%R-HSA-112310.5                          2.716683
# TRANSMISSION ACROSS CHEMICAL SYNAPSES%REACTOME DATABASE ID RELEASE 66%112315    2.701008
# SODIUM ION TRANSMEMBRANE TRANSPORT%GOBP%GO:0035725                              2.694382
# NEURONAL SYSTEM%REACTOME DATABASE ID RELEASE 66%112316                          2.625532
# PHASE 0 - RAPID DEPOLARISATION%REACTOME DATABASE ID RELEASE 66%5576892          2.605634
# MEMBRANE DEPOLARIZATION DURING ACTION POTENTIAL%GOBP%GO:0086010                 2.577240
# CARDIAC CONDUCTION%REACTOME%R-HSA-5576891.2                                     2.528589
# ION CHANNEL TRANSPORT%REACTOME%R-HSA-983712.2                                   2.521400
# MEMBRANE DEPOLARIZATION%GOBP%GO:0051899                                         2.503099
# Name: NES, dtype: float64
#
#
# pathway
# ACTIVATED PKN1 STIMULATES TRANSCRIPTION OF AR (ANDROGEN RECEPTOR) REGULATED GENES KLK2 AND KLK3%REACTOME DATABASE ID RELEASE 66%5625886    2.757991
# SODIUM ION TRANSMEMBRANE TRANSPORT%GOBP%GO:0035725                                                                                         2.749086
# CARDIAC CONDUCTION%REACTOME%R-HSA-5576891.2                                                                                                2.736246
# SODIUM ION TRANSPORT%GOBP%GO:0006814                                                                                                       2.689510
# SIRT1 NEGATIVELY REGULATES RRNA EXPRESSION%REACTOME%R-HSA-427359.2                                                                         2.660500
# RNA POLYMERASE I PROMOTER OPENING%REACTOME DATABASE ID RELEASE 66%73728                                                                    2.648936
# MEMBRANE DEPOLARIZATION%GOBP%GO:0051899                                                                                                    2.647703
# DNA METHYLATION%REACTOME DATABASE ID RELEASE 66%5334118                                                                                    2.628202
# ION HOMEOSTASIS%REACTOME%R-HSA-5578775.1                                                                                                   2.613741
# ION CHANNEL TRANSPORT%REACTOME%R-HSA-983712.2                                                                                              2.563601
# Name: NES, dtype: float64
#
#
#
# TARGET-30-PAPLSD-01
# pathway
# EUKARYOTIC TRANSLATION ELONGATION%REACTOME DATABASE ID RELEASE 66%156842                                               6.622726
# PEPTIDE CHAIN ELONGATION%REACTOME DATABASE ID RELEASE 66%156902                                                        6.570978
# FORMATION OF A POOL OF FREE 40S SUBUNITS%REACTOME DATABASE ID RELEASE 66%72689                                         6.491112
# VIRAL MRNA TRANSLATION%REACTOME%R-HSA-192823.3                                                                         6.417196
# SELENOCYSTEINE SYNTHESIS%REACTOME%R-HSA-2408557.2                                                                      6.405705
# CYTOPLASMIC RIBOSOMAL PROTEINS%WIKIPATHWAYS_20181110%WP477%HOMO SAPIENS                                                6.369409
# EUKARYOTIC TRANSLATION TERMINATION%REACTOME%R-HSA-72764.4                                                              6.325914
# NONSENSE MEDIATED DECAY (NMD) INDEPENDENT OF THE EXON JUNCTION COMPLEX (EJC)%REACTOME DATABASE ID RELEASE 66%975956    6.194035
# SELENOAMINO ACID METABOLISM%REACTOME%R-HSA-2408522.2                                                                   6.113919
# SRP-DEPENDENT COTRANSLATIONAL PROTEIN TARGETING TO MEMBRANE%GOBP%GO:0006614                                            6.100698
# Name: NES, dtype: float64
#
#
# pathway
# EUKARYOTIC TRANSLATION ELONGATION%REACTOME DATABASE ID RELEASE 66%156842                                               5.091100
# PEPTIDE CHAIN ELONGATION%REACTOME DATABASE ID RELEASE 66%156902                                                        5.054383
# VIRAL MRNA TRANSLATION%REACTOME%R-HSA-192823.3                                                                         4.912189
# SELENOCYSTEINE SYNTHESIS%REACTOME%R-HSA-2408557.2                                                                      4.897108
# CYTOPLASMIC RIBOSOMAL PROTEINS%WIKIPATHWAYS_20181110%WP477%HOMO SAPIENS                                                4.835461
# FORMATION OF A POOL OF FREE 40S SUBUNITS%REACTOME DATABASE ID RELEASE 66%72689                                         4.755172
# EUKARYOTIC TRANSLATION TERMINATION%REACTOME%R-HSA-72764.4                                                              4.749347
# NONSENSE MEDIATED DECAY (NMD) INDEPENDENT OF THE EXON JUNCTION COMPLEX (EJC)%REACTOME DATABASE ID RELEASE 66%975956    4.604454
# HALLMARK_INTERFERON_ALPHA_RESPONSE%MSIGDB_C2%HALLMARK_INTERFERON_ALPHA_RESPONSE                                        4.563207
# SRP-DEPENDENT COTRANSLATIONAL PROTEIN TARGETING TO MEMBRANE%GOBP%GO:0006614                                            4.548703
# Name: NES, dtype: float64
#
#
#
# TARGET-30-PARGKK-01
# pathway
# ION CHANNEL TRANSPORT%REACTOME%R-HSA-983712.2                                   2.678310
# ION TRANSPORT BY P-TYPE ATPASES%REACTOME DATABASE ID RELEASE 66%936837          2.654002
# TRANSMISSION ACROSS CHEMICAL SYNAPSES%REACTOME DATABASE ID RELEASE 66%112315    2.636575
# UPTAKE AND ACTIONS OF BACTERIAL TOXINS%REACTOME%R-HSA-5339562.2                 2.636400
# VESICLE-MEDIATED TRANSPORT IN SYNAPSE%GOBP%GO:0099003                           2.621703
# SYNAPTIC VESICLE LOCALIZATION%GOBP%GO:0097479                                   2.597836
# REGULATION OF MACROAUTOPHAGY%GOBP%GO:0016241                                    2.562923
# NEUROTRANSMITTER SECRETION%GOBP%GO:0007269                                      2.555800
# SIGNAL RELEASE FROM SYNAPSE%GOBP%GO:0099643                                     2.555800
# ESTABLISHMENT OF SYNAPTIC VESICLE LOCALIZATION%GOBP%GO:0097480                  2.555682
# Name: NES, dtype: float64
#
#
# pathway
# SYNAPTIC VESICLE LOCALIZATION%GOBP%GO:0097479                     2.541513
# ESTABLISHMENT OF SYNAPTIC VESICLE LOCALIZATION%GOBP%GO:0097480    2.507393
# SYNAPTIC VESICLE TRANSPORT%GOBP%GO:0048489                        2.507393
# ION CHANNEL TRANSPORT%REACTOME%R-HSA-983712.2                     2.492062
# SIGNAL RELEASE FROM SYNAPSE%GOBP%GO:0099643                       2.483346
# NEUROTRANSMITTER SECRETION%GOBP%GO:0007269                        2.483346
# REGULATION OF SYNAPTIC PLASTICITY%GOBP%GO:0048167                 2.479694
# SYNAPTIC VESICLE EXOCYTOSIS%GOBP%GO:0016079                       2.422778
# ACYLGLYCEROL METABOLIC PROCESS%GOBP%GO:0006639                    2.422774
# NEUTRAL LIPID METABOLIC PROCESS%GOBP%GO:0006638                   2.422774
# Name: NES, dtype: float64
# TARGET-30-PARHAM-01
# pathway
# CHOLESTEROL BIOSYNTHETIC PROCESS%GOBP%GO:0006695                     2.896215
# CHOLESTEROL BIOSYNTHESIS%REACTOME DATABASE ID RELEASE 66%191273      2.896120
# TRANS-SYNAPTIC SIGNALING%GOBP%GO:0099537                             2.885954
# SECONDARY ALCOHOL BIOSYNTHETIC PROCESS%GOBP%GO:1902653               2.882130
# CHEMICAL SYNAPTIC TRANSMISSION%GOBP%GO:0007268                       2.877482
# ANTEROGRADE TRANS-SYNAPTIC SIGNALING%GOBP%GO:0098916                 2.877482
# SYNAPTIC SIGNALING%GOBP%GO:0099536                                   2.873375
# SUPERPATHWAY OF CHOLESTEROL BIOSYNTHESIS%HUMANCYC%PWY66-5            2.857506
# CHOLESTEROL BIOSYNTHESIS%WIKIPATHWAYS_20181110%WP197%HOMO SAPIENS    2.815848
# STEROL BIOSYNTHETIC PROCESS%GOBP%GO:0016126                          2.793880
# Name: NES, dtype: float64
#
#
# pathway
# CADHERIN SIGNALING PATHWAY%PANTHER PATHWAY%P00012                                                  2.939190
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION%MSIGDB_C2%HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION    2.914479
# COLLAGEN FORMATION%REACTOME%R-HSA-1474290.1                                                        2.911221
# ASSEMBLY OF COLLAGEN FIBRILS AND OTHER MULTIMERIC STRUCTURES%REACTOME%R-HSA-2022090.3              2.900850
# SYNAPSE ORGANIZATION%GOBP%GO:0050808                                                               2.755148
# TRANS-SYNAPTIC SIGNALING%GOBP%GO:0099537                                                           2.727781
# SYNAPTIC SIGNALING%GOBP%GO:0099536                                                                 2.703974
# CHEMICAL SYNAPTIC TRANSMISSION%GOBP%GO:0007268                                                     2.690776
# ANTEROGRADE TRANS-SYNAPTIC SIGNALING%GOBP%GO:0098916                                               2.690776
# SUPERPATHWAY OF CHOLESTEROL BIOSYNTHESIS%HUMANCYC%PWY66-5                                          2.684286
# Name: NES, dtype: float64
#
#
#
# TARGET-30-PARHAM-02
# pathway
# TRANS-SYNAPTIC SIGNALING%GOBP%GO:0099537                                        3.676263
# SYNAPTIC SIGNALING%GOBP%GO:0099536                                              3.657097
# ANTEROGRADE TRANS-SYNAPTIC SIGNALING%GOBP%GO:0098916                            3.657078
# CHEMICAL SYNAPTIC TRANSMISSION%GOBP%GO:0007268                                  3.657078
# CHOLESTEROL BIOSYNTHESIS%WIKIPATHWAYS_20181110%WP197%HOMO SAPIENS               3.499301
# TRANSMISSION ACROSS CHEMICAL SYNAPSES%REACTOME DATABASE ID RELEASE 66%112315    3.454233
# STEROL BIOSYNTHETIC PROCESS%GOBP%GO:0016126                                     3.439711
# HALLMARK_PROTEIN_SECRETION%MSIGDB_C2%HALLMARK_PROTEIN_SECRETION                 3.405136
# AXO-DENDRITIC TRANSPORT%GOBP%GO:0008088                                         3.399918
# SYNAPSE ORGANIZATION%GOBP%GO:0050808                                            3.340512
# Name: NES, dtype: float64
#
#
# pathway
# CHEMICAL SYNAPTIC TRANSMISSION%GOBP%GO:0007268                                  3.773037
# ANTEROGRADE TRANS-SYNAPTIC SIGNALING%GOBP%GO:0098916                            3.773037
# SYNAPTIC SIGNALING%GOBP%GO:0099536                                              3.764650
# TRANS-SYNAPTIC SIGNALING%GOBP%GO:0099537                                        3.758677
# SYNAPSE ORGANIZATION%GOBP%GO:0050808                                            3.542904
# SIGNAL RELEASE FROM SYNAPSE%GOBP%GO:0099643                                     3.440707
# NEUROTRANSMITTER SECRETION%GOBP%GO:0007269                                      3.440707
# TRANSMISSION ACROSS CHEMICAL SYNAPSES%REACTOME DATABASE ID RELEASE 66%112315    3.402722
# SYNAPTIC VESICLE CYCLE%GOBP%GO:0099504                                          3.358755
# REGULATION OF TRANSPORTER ACTIVITY%GOBP%GO:0032409                              3.311510
# Name: NES, dtype: float64
#
#
#
# TARGET-30-PASPER-01
# pathway
# FORMATION OF A POOL OF FREE 40S SUBUNITS%REACTOME DATABASE ID RELEASE 66%72689                              2.923362
# L13A-MEDIATED TRANSLATIONAL SILENCING OF CERULOPLASMIN EXPRESSION%REACTOME DATABASE ID RELEASE 66%156827    2.875611
# CYTOPLASMIC RIBOSOMAL PROTEINS%WIKIPATHWAYS_20181110%WP477%HOMO SAPIENS                                     2.856983
# TRANSLATIONAL INITIATION%GOBP%GO:0006413                                                                    2.848847
# GTP HYDROLYSIS AND JOINING OF THE 60S RIBOSOMAL SUBUNIT%REACTOME DATABASE ID RELEASE 66%72706               2.842695
# PEPTIDE CHAIN ELONGATION%REACTOME DATABASE ID RELEASE 66%156902                                             2.792042
# VIRAL MRNA TRANSLATION%REACTOME%R-HSA-192823.3                                                              2.790945
# SELENOCYSTEINE SYNTHESIS%REACTOME%R-HSA-2408557.2                                                           2.759451
# CAP-DEPENDENT TRANSLATION INITIATION%REACTOME DATABASE ID RELEASE 66%72737                                  2.757388
# EUKARYOTIC TRANSLATION INITIATION%REACTOME DATABASE ID RELEASE 66%72613                                     2.757388
# Name: NES, dtype: float64
#
#
# pathway
# HALLMARK_INTERFERON_ALPHA_RESPONSE%MSIGDB_C2%HALLMARK_INTERFERON_ALPHA_RESPONSE    3.101950
# HALLMARK_INTERFERON_GAMMA_RESPONSE%MSIGDB_C2%HALLMARK_INTERFERON_GAMMA_RESPONSE    2.923961
# COMPLEMENT ACTIVATION, CLASSICAL PATHWAY%GOBP%GO:0006958                           2.874194
# B CELL RECEPTOR SIGNALING PATHWAY%GOBP%GO:0050853                                  2.776246
# DEFENSE RESPONSE TO VIRUS%GOBP%GO:0051607                                          2.752991
# HUMORAL IMMUNE RESPONSE MEDIATED BY CIRCULATING IMMUNOGLOBULIN%GOBP%GO:0002455     2.736728
# COMPLEMENT ACTIVATION%GOBP%GO:0006956                                              2.670430
# TYPE I INTERFERON SIGNALING PATHWAY%GOBP%GO:0060337                                2.667439
# CELLULAR RESPONSE TO TYPE I INTERFERON%GOBP%GO:0071357                             2.667439
# RESPONSE TO TYPE I INTERFERON%GOBP%GO:0034340                                      2.647166
# Name: NES, dtype: float64
#
#
#
# TARGET-30-PASSRS-01
# pathway
# NON-MOTILE CILIUM ASSEMBLY%GOBP%GO:1905515                                   2.307855
# REGULATION OF SMOOTHENED SIGNALING PATHWAY%GOBP%GO:0008589                   2.224800
# CILIUM ASSEMBLY%REACTOME%R-HSA-5617833.3                                     2.176795
# CILIUM ORGANIZATION%GOBP%GO:0044782                                          2.142447
# TRNA PROCESSING%REACTOME DATABASE ID RELEASE 66%72306                        2.124252
# PRODUCTION OF MIRNAS INVOLVED IN GENE SILENCING BY MIRNA%GOBP%GO:0035196     2.119425
# GPI ANCHOR BIOSYNTHETIC PROCESS%GOBP%GO:0006506                              2.082513
# PRODUCTION OF SMALL RNA INVOLVED IN GENE SILENCING BY RNA%GOBP%GO:0070918    2.079408
# DSRNA PROCESSING%GOBP%GO:0031050                                             2.079408
# CILIUM ASSEMBLY%GOBP%GO:0060271                                              2.075415
# Name: NES, dtype: float64
#
#
# Series([], Name: NES, dtype: float64)
#
#
#
# TARGET-30-PASUCB-01
# pathway
# HALLMARK_MYC_TARGETS_V1%MSIGDB_C2%HALLMARK_MYC_TARGETS_V1                                                   3.592079
# MAJOR PATHWAY OF RRNA PROCESSING IN THE NUCLEOLUS AND CYTOSOL%REACTOME DATABASE ID RELEASE 66%6791226       3.471938
# RRNA PROCESSING IN THE NUCLEUS AND CYTOSOL%REACTOME%R-HSA-8868773.2                                         3.468037
# TRANSLATION%GOBP%GO:0006412                                                                                 3.426518
# RRNA PROCESSING%REACTOME DATABASE ID RELEASE 66%72312                                                       3.371812
# HALLMARK_E2F_TARGETS%MSIGDB_C2%HALLMARK_E2F_TARGETS                                                         3.350417
# TRANSLATION%REACTOME%R-HSA-72766.3                                                                          3.332316
# PEPTIDE BIOSYNTHETIC PROCESS%GOBP%GO:0043043                                                                3.315814
# RIBOSOME BIOGENESIS%GOBP%GO:0042254                                                                         3.238260
# L13A-MEDIATED TRANSLATIONAL SILENCING OF CERULOPLASMIN EXPRESSION%REACTOME DATABASE ID RELEASE 66%156827    3.235640
# Name: NES, dtype: float64
#
#
# pathway
# HALLMARK_E2F_TARGETS%MSIGDB_C2%HALLMARK_E2F_TARGETS                        3.438796
# HALLMARK_G2M_CHECKPOINT%MSIGDB_C2%HALLMARK_G2M_CHECKPOINT                  3.296422
# RETINOBLASTOMA GENE IN CANCER%WIKIPATHWAYS_20181110%WP2446%HOMO SAPIENS    2.846434
# DNA REPLICATION%GOBP%GO:0006260                                            2.829559
# PROTEIN EXPORT FROM NUCLEUS%GOBP%GO:0006611                                2.762518
# HALLMARK_MYC_TARGETS_V1%MSIGDB_C2%HALLMARK_MYC_TARGETS_V1                  2.738464
# CHROMATIN ASSEMBLY OR DISASSEMBLY%GOBP%GO:0006333                          2.733125
# NUCLEAR EXPORT%GOBP%GO:0051168                                             2.708684
# NUCLEOSOME ORGANIZATION%GOBP%GO:0034728                                    2.705080
# RNA EXPORT FROM NUCLEUS%GOBP%GO:0006405                                    2.697863
# Name: NES, dtype: float64
#
#
#
# TARGET-30-PASUYG-01
# pathway
# HALLMARK_E2F_TARGETS%MSIGDB_C2%HALLMARK_E2F_TARGETS                                                        5.088970
# DEPOSITION OF NEW CENPA-CONTAINING NUCLEOSOMES AT THE CENTROMERE%REACTOME DATABASE ID RELEASE 66%606279    4.575068
# NUCLEOSOME ASSEMBLY%REACTOME%R-HSA-774815.1                                                                4.575068
# CHROMOSOME MAINTENANCE%REACTOME DATABASE ID RELEASE 66%73886                                               4.500510
# MEIOTIC RECOMBINATION%REACTOME DATABASE ID RELEASE 66%912446                                               4.432555
# CONDENSATION OF PROPHASE CHROMOSOMES%REACTOME%R-HSA-2299718.1                                              4.422548
# DNA METHYLATION%REACTOME DATABASE ID RELEASE 66%5334118                                                    4.326884
# TELOMERE MAINTENANCE%REACTOME DATABASE ID RELEASE 66%157579                                                4.274635
# B-WICH COMPLEX POSITIVELY REGULATES RRNA EXPRESSION%REACTOME%R-HSA-5250924.2                               4.147911
# SIRT1 NEGATIVELY REGULATES RRNA EXPRESSION%REACTOME%R-HSA-427359.2                                         4.060712
# Name: NES, dtype: float64
#
#
# pathway
# HALLMARK_E2F_TARGETS%MSIGDB_C2%HALLMARK_E2F_TARGETS                                                                                        4.955814
# CONDENSATION OF PROPHASE CHROMOSOMES%REACTOME%R-HSA-2299718.1                                                                              4.929425
# CHROMOSOME MAINTENANCE%REACTOME DATABASE ID RELEASE 66%73886                                                                               4.793007
# DNA METHYLATION%REACTOME DATABASE ID RELEASE 66%5334118                                                                                    4.783070
# DEPOSITION OF NEW CENPA-CONTAINING NUCLEOSOMES AT THE CENTROMERE%REACTOME DATABASE ID RELEASE 66%606279                                    4.694822
# NUCLEOSOME ASSEMBLY%REACTOME%R-HSA-774815.1                                                                                                4.694822
# MEIOTIC RECOMBINATION%REACTOME DATABASE ID RELEASE 66%912446                                                                               4.606993
# TELOMERE MAINTENANCE%REACTOME DATABASE ID RELEASE 66%157579                                                                                4.605105
# ACTIVATED PKN1 STIMULATES TRANSCRIPTION OF AR (ANDROGEN RECEPTOR) REGULATED GENES KLK2 AND KLK3%REACTOME DATABASE ID RELEASE 66%5625886    4.448172
# RNA POLYMERASE I PROMOTER OPENING%REACTOME DATABASE ID RELEASE 66%73728                                                                    4.434508
# Name: NES, dtype: float64
# TARGET-30-PATCFL-01
# pathway
# FORMATION OF A POOL OF FREE 40S SUBUNITS%REACTOME DATABASE ID RELEASE 66%72689                                         3.379617
# EUKARYOTIC TRANSLATION ELONGATION%REACTOME DATABASE ID RELEASE 66%156842                                               3.350634
# PEPTIDE CHAIN ELONGATION%REACTOME DATABASE ID RELEASE 66%156902                                                        3.273316
# EUKARYOTIC TRANSLATION TERMINATION%REACTOME%R-HSA-72764.4                                                              3.211802
# VIRAL MRNA TRANSLATION%REACTOME%R-HSA-192823.3                                                                         3.179152
# SELENOCYSTEINE SYNTHESIS%REACTOME%R-HSA-2408557.2                                                                      3.176783
# SRP-DEPENDENT COTRANSLATIONAL PROTEIN TARGETING TO MEMBRANE%GOBP%GO:0006614                                            3.117029
# CYTOPLASMIC RIBOSOMAL PROTEINS%WIKIPATHWAYS_20181110%WP477%HOMO SAPIENS                                                3.069897
# RIBOSOMAL LARGE SUBUNIT BIOGENESIS%GOBP%GO:0042273                                                                     2.970595
# NONSENSE MEDIATED DECAY (NMD) INDEPENDENT OF THE EXON JUNCTION COMPLEX (EJC)%REACTOME DATABASE ID RELEASE 66%975956    2.914663
# Name: NES, dtype: float64
#
#
# pathway
# HUMORAL IMMUNE RESPONSE MEDIATED BY CIRCULATING IMMUNOGLOBULIN%GOBP%GO:0002455    2.920015
# COMPLEMENT ACTIVATION, CLASSICAL PATHWAY%GOBP%GO:0006958                          2.863992
# REGULATION OF COMPLEMENT CASCADE%REACTOME DATABASE ID RELEASE 66%977606           2.769753
# COMPLEMENT ACTIVATION%GOBP%GO:0006956                                             2.740233
# COMPLEMENT CASCADE%REACTOME DATABASE ID RELEASE 66%166658                         2.728537
# INITIAL TRIGGERING OF COMPLEMENT%REACTOME DATABASE ID RELEASE 66%166663           2.675531
# CLASSICAL ANTIBODY-MEDIATED COMPLEMENT ACTIVATION%REACTOME%R-HSA-173623.2         2.452777
# B CELL RECEPTOR SIGNALING PATHWAY%GOBP%GO:0050853                                 2.423545
# SARCOMERE ORGANIZATION%GOBP%GO:0045214                                            2.308060
# REGULATION OF COMPLEMENT ACTIVATION%GOBP%GO:0030449                               2.290777
# Name: NES, dtype: float64
#
#
#
# TARGET-30-PATFCY-01
# pathway
# MITOCHONDRIAL GENE EXPRESSION%GOBP%GO:0140053              2.682726
# INTRACILIARY TRANSPORT%GOBP%GO:0042073                     2.671273
# MITOCHONDRIAL TRANSLATION%GOBP%GO:0032543                  2.656671
# RIBOSOME BIOGENESIS%GOBP%GO:0042254                        2.652277
# TRANSLATION%REACTOME%R-HSA-72766.3                         2.637856
# MITOCHONDRIAL TRANSLATIONAL TERMINATION%GOBP%GO:0070126    2.608504
# RRNA PROCESSING%GOBP%GO:0006364                            2.598257
# REGULATION OF MITOCHONDRIAL TRANSLATION%GOBP%GO:0070129    2.593812
# CILIUM ASSEMBLY%REACTOME%R-HSA-5617833.3                   2.593776
# TRANSLATION%GOBP%GO:0006412                                2.592555
# Name: NES, dtype: float64
#
#
# Series([], Name: NES, dtype: float64)
#
#
#
# TARGET-30-PATHVK-01
# pathway
# MAJOR PATHWAY OF RRNA PROCESSING IN THE NUCLEOLUS AND CYTOSOL%REACTOME DATABASE ID RELEASE 66%6791226       3.796152
# RRNA PROCESSING IN THE NUCLEUS AND CYTOSOL%REACTOME%R-HSA-8868773.2                                         3.785807
# RRNA PROCESSING%REACTOME DATABASE ID RELEASE 66%72312                                                       3.754234
# RIBOSOME BIOGENESIS%GOBP%GO:0042254                                                                         3.636994
# FORMATION OF A POOL OF FREE 40S SUBUNITS%REACTOME DATABASE ID RELEASE 66%72689                              3.626533
# EUKARYOTIC TRANSLATION INITIATION%REACTOME DATABASE ID RELEASE 66%72613                                     3.560343
# CAP-DEPENDENT TRANSLATION INITIATION%REACTOME DATABASE ID RELEASE 66%72737                                  3.560343
# RRNA PROCESSING%GOBP%GO:0006364                                                                             3.537046
# GTP HYDROLYSIS AND JOINING OF THE 60S RIBOSOMAL SUBUNIT%REACTOME DATABASE ID RELEASE 66%72706               3.486410
# L13A-MEDIATED TRANSLATIONAL SILENCING OF CERULOPLASMIN EXPRESSION%REACTOME DATABASE ID RELEASE 66%156827    3.478588
# Name: NES, dtype: float64
#
#
# pathway
# HALLMARK_E2F_TARGETS%MSIGDB_C2%HALLMARK_E2F_TARGETS                                                      2.805480
# ACTIVATION OF THE PRE-REPLICATIVE COMPLEX%REACTOME%R-HSA-68962.3                                         2.596990
# MAJOR PATHWAY OF RRNA PROCESSING IN THE NUCLEOLUS AND CYTOSOL%REACTOME DATABASE ID RELEASE 66%6791226    2.504973
# RRNA PROCESSING IN THE NUCLEUS AND CYTOSOL%REACTOME%R-HSA-8868773.2                                      2.469314
# DNA REPLICATION%WIKIPATHWAYS_20181110%WP466%HOMO SAPIENS                                                 2.446280
# TRANSCRIPTIONAL REGULATION BY SMALL RNAS%REACTOME DATABASE ID RELEASE 66%5578749                         2.434642
# ACTIVATION OF ATR IN RESPONSE TO REPLICATION STRESS%REACTOME%R-HSA-176187.2                              2.425904
# DETECTION OF CHEMICAL STIMULUS INVOLVED IN SENSORY PERCEPTION OF TASTE%GOBP%GO:0050912                   2.422474
# DETECTION OF CHEMICAL STIMULUS INVOLVED IN SENSORY PERCEPTION%GOBP%GO:0050907                            2.422474
# NUCLEOSOME ASSEMBLY%GOBP%GO:0006334                                                                      2.421558
# Name: NES, dtype: float64
#
#
#
# TARGET-30-PATNKP-02
# pathway
# HALLMARK_E2F_TARGETS%MSIGDB_C2%HALLMARK_E2F_TARGETS                                2.937524
# MITOCHONDRIAL GENE EXPRESSION%GOBP%GO:0140053                                      2.914448
# HALLMARK_G2M_CHECKPOINT%MSIGDB_C2%HALLMARK_G2M_CHECKPOINT                          2.819742
# RESOLUTION OF SISTER CHROMATID COHESION%REACTOME DATABASE ID RELEASE 66%2500257    2.753415
# MITOCHONDRIAL TRANSLATION%GOBP%GO:0032543                                          2.751732
# HALLMARK_MYC_TARGETS_V1%MSIGDB_C2%HALLMARK_MYC_TARGETS_V1                          2.695528
# MITOCHONDRIAL TRANSLATIONAL ELONGATION%GOBP%GO:0070125                             2.650409
# MITOCHONDRIAL TRANSLATION%REACTOME DATABASE ID RELEASE 66%5368287                  2.643612
# MITOTIC METAPHASE AND ANAPHASE%REACTOME DATABASE ID RELEASE 66%2555396             2.640972
# MITOTIC ANAPHASE%REACTOME%R-HSA-68882.2                                            2.631634
# Name: NES, dtype: float64
#
#
# pathway
# HALLMARK_E2F_TARGETS%MSIGDB_C2%HALLMARK_E2F_TARGETS                                                                         2.897057
# HALLMARK_G2M_CHECKPOINT%MSIGDB_C2%HALLMARK_G2M_CHECKPOINT                                                                   2.845447
# RESOLUTION OF SISTER CHROMATID COHESION%REACTOME DATABASE ID RELEASE 66%2500257                                             2.771055
# MITOTIC SPINDLE CHECKPOINT%REACTOME%R-HSA-69618.2                                                                           2.664212
# SEPARATION OF SISTER CHROMATIDS%REACTOME%R-HSA-2467813.1                                                                    2.662353
# MITOTIC METAPHASE AND ANAPHASE%REACTOME DATABASE ID RELEASE 66%2555396                                                      2.661336
# MITOTIC ANAPHASE%REACTOME%R-HSA-68882.2                                                                                     2.650961
# AMPLIFICATION OF SIGNAL FROM THE KINETOCHORES%REACTOME%R-HSA-141424.2                                                       2.577747
# AMPLIFICATION OF SIGNAL FROM UNATTACHED KINETOCHORES VIA A MAD2 INHIBITORY SIGNAL%REACTOME DATABASE ID RELEASE 66%141444    2.577747
# S PHASE%REACTOME DATABASE ID RELEASE 66%69242                                                                               2.576104
# Name: NES, dtype: float64
#
#
#
# TARGET-30-PATYIL-01
# pathway
# TRANSLATION%GOBP%GO:0006412                                                                                 3.632606
# TRANSLATION%REACTOME%R-HSA-72766.3                                                                          3.585657
# PEPTIDE BIOSYNTHETIC PROCESS%GOBP%GO:0043043                                                                3.546614
# PYRUVATE METABOLIC PROCESS%GOBP%GO:0006090                                                                  3.491409
# AMIDE BIOSYNTHETIC PROCESS%GOBP%GO:0043604                                                                  3.486669
# HALLMARK_MYC_TARGETS_V1%MSIGDB_C2%HALLMARK_MYC_TARGETS_V1                                                   3.461859
# CAP-DEPENDENT TRANSLATION INITIATION%REACTOME DATABASE ID RELEASE 66%72737                                  3.389880
# EUKARYOTIC TRANSLATION INITIATION%REACTOME DATABASE ID RELEASE 66%72613                                     3.389880
# TRANSLATIONAL INITIATION%GOBP%GO:0006413                                                                    3.371942
# L13A-MEDIATED TRANSLATIONAL SILENCING OF CERULOPLASMIN EXPRESSION%REACTOME DATABASE ID RELEASE 66%156827    3.348572
# Name: NES, dtype: float64
#
#
# pathway
# METABOLIC REPROGRAMMING IN COLON CANCER%WIKIPATHWAYS_20181110%WP4290%HOMO SAPIENS    3.355036
# HALLMARK_MTORC1_SIGNALING%MSIGDB_C2%HALLMARK_MTORC1_SIGNALING                        3.187211
# CHOLESTEROL BIOSYNTHESIS%WIKIPATHWAYS_20181110%WP197%HOMO SAPIENS                    3.139571
# GLYCOLYSIS AND GLUCONEOGENESIS%WIKIPATHWAYS_20181110%WP534%HOMO SAPIENS              3.108907
# PYRUVATE METABOLIC PROCESS%GOBP%GO:0006090                                           3.090564
# ALCOHOL BIOSYNTHETIC PROCESS%GOBP%GO:0046165                                         3.061813
# GLUCONEOGENESIS%GOBP%GO:0006094                                                      3.034348
# ATP GENERATION FROM ADP%GOBP%GO:0006757                                              3.019587
# GLYCOLYTIC PROCESS%GOBP%GO:0006096                                                   3.010513
# SUPERPATHWAY OF CHOLESTEROL BIOSYNTHESIS%HUMANCYC%PWY66-5                            2.996730
# Name: NES, dtype: float64
#
#
#
# TARGET-30-PATYIL-02
# pathway
# TRANSLATIONAL INITIATION%GOBP%GO:0006413                                                                               5.117673
# L13A-MEDIATED TRANSLATIONAL SILENCING OF CERULOPLASMIN EXPRESSION%REACTOME DATABASE ID RELEASE 66%156827               5.105663
# GTP HYDROLYSIS AND JOINING OF THE 60S RIBOSOMAL SUBUNIT%REACTOME DATABASE ID RELEASE 66%72706                          5.085625
# HALLMARK_MYC_TARGETS_V1%MSIGDB_C2%HALLMARK_MYC_TARGETS_V1                                                              5.032347
# EUKARYOTIC TRANSLATION INITIATION%REACTOME DATABASE ID RELEASE 66%72613                                                5.026776
# CAP-DEPENDENT TRANSLATION INITIATION%REACTOME DATABASE ID RELEASE 66%72737                                             5.026776
# FORMATION OF A POOL OF FREE 40S SUBUNITS%REACTOME DATABASE ID RELEASE 66%72689                                         5.012091
# TRANSLATION%REACTOME%R-HSA-72766.3                                                                                     4.944255
# EUKARYOTIC TRANSLATION ELONGATION%REACTOME DATABASE ID RELEASE 66%156842                                               4.891974
# NONSENSE MEDIATED DECAY (NMD) INDEPENDENT OF THE EXON JUNCTION COMPLEX (EJC)%REACTOME DATABASE ID RELEASE 66%975956    4.854554
# Name: NES, dtype: float64
#
#
# pathway
# L13A-MEDIATED TRANSLATIONAL SILENCING OF CERULOPLASMIN EXPRESSION%REACTOME DATABASE ID RELEASE 66%156827               4.697305
# GTP HYDROLYSIS AND JOINING OF THE 60S RIBOSOMAL SUBUNIT%REACTOME DATABASE ID RELEASE 66%72706                          4.682348
# FORMATION OF A POOL OF FREE 40S SUBUNITS%REACTOME DATABASE ID RELEASE 66%72689                                         4.649642
# HALLMARK_MYC_TARGETS_V1%MSIGDB_C2%HALLMARK_MYC_TARGETS_V1                                                              4.617183
# EUKARYOTIC TRANSLATION ELONGATION%REACTOME DATABASE ID RELEASE 66%156842                                               4.616688
# TRANSLATIONAL INITIATION%GOBP%GO:0006413                                                                               4.593612
# NONSENSE MEDIATED DECAY (NMD) INDEPENDENT OF THE EXON JUNCTION COMPLEX (EJC)%REACTOME DATABASE ID RELEASE 66%975956    4.567293
# CAP-DEPENDENT TRANSLATION INITIATION%REACTOME DATABASE ID RELEASE 66%72737                                             4.554626
# EUKARYOTIC TRANSLATION INITIATION%REACTOME DATABASE ID RELEASE 66%72613                                                4.554626
# PEPTIDE CHAIN ELONGATION%REACTOME DATABASE ID RELEASE 66%156902                                                        4.536635
# Name: NES, dtype: float64

# %%
cluster2_immune
# Out:
# ['TARGET-30-PALNVP-01',
#  'TARGET-30-PALUYS-01',
#  'TARGET-30-PALXTB-01',
#  'TARGET-30-PANUIF-01',
#  'TARGET-30-PAPLSD-01',
#  'TARGET-30-PARGKK-01',
#  'TARGET-30-PARHAM-02',
#  'TARGET-30-PASPER-01',
#  'TARGET-30-PASUYG-01',
#  'TARGET-30-PATCFL-01',
#  'TARGET-30-PATYIL-02']

# %%
for cluster, counts in sub_cohort_unique.items():
    print cluster, len(assign[assign['1'] == cluster])
    
    counter = collections.Counter(counts)
    
    for gs, n in counter.most_common(10):
        print gs, n
    
    print '\n\n'
# Out:
# 1 31
# POSITIVE T CELL SELECTION%GOBP%GO:0043368 24
# THYMIC T CELL SELECTION%GOBP%GO:0045061 23
# POSITIVE THYMIC T CELL SELECTION%GOBP%GO:0045059 23
# T CELL SELECTION%GOBP%GO:0045058 21
# T CELL DIFFERENTIATION IN THYMUS%GOBP%GO:0033077 20
# BIOCARTA_TCYTOTOXIC_PATHWAY%MSIGDB_C2%BIOCARTA_TCYTOTOXIC_PATHWAY 20
# T CELL DIFFERENTIATION%GOBP%GO:0030217 20
# BIOCARTA_THELPER_PATHWAY%MSIGDB_C2%BIOCARTA_THELPER_PATHWAY 20
# BIOCARTA_TCRA_PATHWAY%MSIGDB_C2%BIOCARTA_TCRA_PATHWAY 19
# ESTABLISHMENT OF T CELL POLARITY%GOBP%GO:0001768 19
#
#
#
# 2 26
# MITOCHONDRIAL TRANSLATIONAL ELONGATION%GOBP%GO:0070125 12
# TRNA CHARGING%HUMANCYC%TRNA-CHARGING-PWY 11
# MITOCHONDRIAL TRANSLATION ELONGATION%REACTOME DATABASE ID RELEASE 66%5389840 11
# MITOCHONDRIAL TRANSLATION%REACTOME DATABASE ID RELEASE 66%5368287 11
# ELECTRON TRANSPORT CHAIN (OXPHOS SYSTEM IN MITOCHONDRIA)%WIKIPATHWAYS_20181110%WP111%HOMO SAPIENS 11
# MITOCHONDRIAL TRANSLATION TERMINATION%REACTOME DATABASE ID RELEASE 66%5419276 11
# MITOCHONDRIAL TRANSLATION%GOBP%GO:0032543 11
# RESPIRATORY ELECTRON TRANSPORT, ATP SYNTHESIS BY CHEMIOSMOTIC COUPLING, AND HEAT PRODUCTION BY UNCOUPLING PROTEINS.%REACTOME%R-HSA-163200.1 11
# CELLULAR RESPIRATION%GOBP%GO:0045333 11
# TRNA AMINOACYLATION%REACTOME DATABASE ID RELEASE 66%379724 11
#
#
#
# 3 13
# CARDIAC CHAMBER MORPHOGENESIS%GOBP%GO:0003206 11
# EMBRYONIC MORPHOGENESIS%GOBP%GO:0048598 11
# POSITIVE REGULATION OF WOUND HEALING%GOBP%GO:0090303 11
# TGF-BETA RECEPTOR SIGNALING%WIKIPATHWAYS_20181110%WP560%HOMO SAPIENS 10
# POSITIVE REGULATION OF RESPONSE TO WOUNDING%GOBP%GO:1903036 10
# UROGENITAL SYSTEM DEVELOPMENT%GOBP%GO:0001655 10
# MUSCLE STRUCTURE DEVELOPMENT%GOBP%GO:0061061 10
# TGF-BETA SIGNALING PATHWAY%WIKIPATHWAYS_20181110%WP366%HOMO SAPIENS 10
# REGULATION OF VASCULAR ASSOCIATED SMOOTH MUSCLE CELL MIGRATION%GOBP%GO:1904752 10
# SKIN DEVELOPMENT%GOBP%GO:0043588 10

# %%
top5 = []
for cluster, counts in sub_clust_unique.items():
    print cluster, len(assign[assign['1'] == cluster])
    
    counter = collections.Counter(counts)
    
    for gs, n in counter.most_common(5):
        print gs, n
        if cluster == 2:
            top5.append(gs)
    
    print '\n\n'
# Out:
# 1 31
# REGULATION OF VASCULATURE DEVELOPMENT%GOBP%GO:1901342 8
# POSITIVE REGULATION OF LOCOMOTION%GOBP%GO:0040017 8
# PLATELET DEGRANULATION%GOBP%GO:0002576 7
# RESPONSE TO ELEVATED PLATELET CYTOSOLIC CA2+%REACTOME DATABASE ID RELEASE 66%76005 7
# POSITIVE REGULATION OF VASCULATURE DEVELOPMENT%GOBP%GO:1904018 7
#
#
#
# 2 26
# MYELOID CELL ACTIVATION INVOLVED IN IMMUNE RESPONSE%GOBP%GO:0002275 8
# LEUKOCYTE DEGRANULATION%GOBP%GO:0043299 8
# MYELOID LEUKOCYTE MEDIATED IMMUNITY%GOBP%GO:0002444 8
# GRANULOCYTE ACTIVATION%GOBP%GO:0036230 7
# MICROGLIA PATHOGEN PHAGOCYTOSIS PATHWAY%WIKIPATHWAYS_20181110%WP3937%HOMO SAPIENS 7
#
#
#
# 3 13
# CELL CYCLE CHECKPOINTS%REACTOME%R-HSA-69620.1 5
# AMINO ACID AND DERIVATIVE METABOLISM%REACTOME%R-HSA-71291.4 5
# MITOTIC METAPHASE AND ANAPHASE%REACTOME DATABASE ID RELEASE 66%2555396 5
# ACTIVATION OF ATR IN RESPONSE TO REPLICATION STRESS%REACTOME%R-HSA-176187.2 5
# HALLMARK_OXIDATIVE_PHOSPHORYLATION%MSIGDB_C2%HALLMARK_OXIDATIVE_PHOSPHORYLATION 5

# %%
top5
# Out:
# ['MYELOID CELL ACTIVATION INVOLVED IN IMMUNE RESPONSE%GOBP%GO:0002275',
#  'LEUKOCYTE DEGRANULATION%GOBP%GO:0043299',
#  'MYELOID LEUKOCYTE MEDIATED IMMUNITY%GOBP%GO:0002444',
#  'GRANULOCYTE ACTIVATION%GOBP%GO:0036230',
#  'MICROGLIA PATHOGEN PHAGOCYTOSIS PATHWAY%WIKIPATHWAYS_20181110%WP3937%HOMO SAPIENS']

# %%
def get_event(event):
    if pd.isnull(event):
        print("NULL")
        return np.nan
    
    events = ['Relapse',
              'Death', 
              'Progression',
              'Event',
              'Second Malignant Neoplasm']
    
    if event == 'Censored':
        return 0
    
    elif event in events:
        return 1 
    
    else:
        raise ValueError(event)
        
def get_vital(vital):
    if pd.isnull(vital):
        print("NULL")
        return np.nan
    
    
    if vital == 'Alive':
        return 0
    
    elif vital == 'Dead':
        return 1
    
    else:
        raise ValueError(vital)

pth = '../data/meta/TARGET_NBL_ClinicalData_Discovery_20170525.xlsx'
clinical = pd.read_excel(pth, index_col=0)

surv = pd.DataFrame(index=assign[assign['1'] == 2].index, 
                    columns=['OS', 'vital', 'EFS', 'event', 'immune'])

for sample in assign[assign['1'] == 2].index:
    root = '-'.join(sample.split('-')[:3])
    if root not in clinical.index:
        print "Missing: ", sample
        continue
    
    OS = clinical.loc[root, 'Overall Survival Time in Days'].item()
    vital = get_vital(clinical.loc[root, 'Vital Status'])
    
    EFS = clinical.loc[root, 'Event Free Survival Time in Days'].item()
    event = get_event(clinical.loc[root, 'First Event'])
    
    
    immune = 1 if sample in cluster2_immune else 0
    surv.loc[sample, :] = [OS, vital, EFS, event, immune]

# %%
import uuid

# Can't figure out how to pass this dataframe
survpth = '../data/mycn-na-tme-signal-subtract-cluster2-survival.tsv'
surv.to_csv(survpth, sep='\t')

# %%
# %%R -i survpth
#
# require(dpylr)
# require(survival)
# require(survminer)
#
# surv <- read.table(survpth,
#                   sep='\t',
#                   header=T)
#
# surv <- dplyr::as_tibble(surv)
# Out:
# UsageError: Cell magic `%%R` not found.

# %%
# %%R
#
# fit <- survfit(Surv(OS, vital) ~ immune, data=surv)
# g <- ggsurvplot(fit, conf.int=F, pval=T, risk.table=TRUE)
# ggsave( "/home/jpfeil/MEGAsync/Dropbox/hydra-paper/MYCNna/cluster-2-sub-cluster-immune-OS-survival.png",
#        print(g),
#        dpi = 1000 )
# g

# %%
# %%R
#
# fit <- survfit(Surv(EFS, event) ~ immune, data=surv)
# g <- ggsurvplot(fit, conf.int=F, pval=T, risk.table=TRUE)
# ggsave("/home/jpfeil/MEGAsync/Dropbox/hydra-paper/MYCNna/cluster-2-sub-cluster-immune-EFS-survival.png",
#        print(g),
#        dpi = 1000)
